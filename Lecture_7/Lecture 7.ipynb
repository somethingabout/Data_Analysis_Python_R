# %% [markdown]
# # Course: Intro to Python & R for Data Analysis
# ## Lecture: Webscraping
# ### The wildwest of data collection
# Professor: Mary Kaltenberg
#
# Fall 2020
#
# contact: mkaltenberg@pace.edu
#
# About me: www.mkaltenberg.com

# %% [markdown]
# ## Objectives:
#
# * Inspect an HTML page and identify which parts you want to scrape.
# * Scrape web pages with `requests` and `BeautifulSoup`.
# * Ethical consideration (be a good citizen of the Internet).
#
# If we have time in the next class:
# * Web crawling across the internet
# * Navigate Javascript elements with `Selenium`
#
# *Additional information about Selenium is included in this notebook, but not covered in class
#
# <img src="https://media.giphy.com/media/Cjv37jPMVJw0o/giphy.gif" width = 300>
#
# Fun fact: When Google started in 1994, it was just two Stanford graduate students with an old server and a Python web crawler.

# %% [markdown]
# # Webscraping

# %% [markdown]
# Generally, webscraping consists of these things:
# 1. GET request to a web server for a specific page
# 2. Reading the HTML output from that page
# 3. Simple data extraction isolating desired content
# 4. Storing that content somewhere
# 5. (optionally) move to another page to rinse and repeat.
#
# Webscraping typically involves detective work. You will often have to adjust your steps according to the type of data you want, and the steps that worked on one website may not work on another or even work on the same website a few months later. It requires a fair bit of art. But, if you can see it in your browser, you can scrape it.

# %% [markdown]
# ## HTML page structure
#
# **Hypertext Markup Language (HTML)** is the standard markup language for documents designed to be displayed in a web browser. HTML describes the structure of a web page and it can be used with **Cascading Style Sheets (CSS)** and a scripting language such as **JavaScript** to create interactive websites. HTML consists of a series of elements that "tell" to the browser how to display the content. Lastly, elements are represented by **tags**.
#
# Here are some tags:
# * `<!DOCTYPE html>` declaration defines this document to be HTML5.
# * `<html>` element is the root element of an HTML page.
# * `<div>` tag defines a division or a section in an HTML document. It's usually a container for other elements.
# * `<head>` element contains meta information about the document.
# * `<title>` element specifies a title for the document.
# * `<body>` element contains the visible page content.
# * `<h1>` element defines a large heading.
# * `<p>` element defines a paragraph.
# * `<a>` element defines a hyperlink.
#
# HTML tags normally come in pairs like `<p>` and `</p>`. The first tag in a pair is the opening tag, the second tag is the closing tag. The end tag is written like the start tag, but with a slash inserted before the tag name.
#
# <img src="tags.png" width="512">
#
# HTML has a tree-like 🌳 🌲 structure thanks to the **Document Object Model (DOM)**, a cross-platform and language-independent interface. Here's how a very simple HTML tree looks like.
#
# <img src="dom_tree.gif">
#
# ### Creating a simple HTML page

# %% [markdown]
# Here is some simple HTML code of what a webpage looks like (when you run with markdown, it'll show what it might look like on a webpage)

# %% [markdown]
# <!DOCTYPE html>
# <html lang="en" dir="ltr">
# <head>
#   <title>Intro to HTML</title>
# </head>
#
# <body>
#   <h1>Heading h1</h1>
#   <h2>Heading h2</h2>
#   <h3>Heading h3</h3>
#   <h4>Heading h4</h4>
#
#   <p>
#     That's a text paragraph. You can also <b>bold</b>, <mark>mark</mark>, <ins>underline</ins>, <del>strikethrough</del> and <i>emphasize</i> words.
#     You can also add links - here's one to <a href="https://en.wikipedia.org/wiki/Main_Page">Wikipedia</a>.
#   </p>
#
#   <p>
#     This <br> is a paragraph <br> with <br> line breaks
#   </p>
#
#   <p style="color:red">
#     Add colour to your paragraphs.
#   </p>
#
#   <p>Unordered list:</p>
#   <ul>
#     <li>Python</li>
#     <li>R</li>
#     <li>Julia</li>
#   </ul>
#
#   <p>Ordered list:</p>
#   <ol>
#     <li>Data collection</li>
#     <li>Exploratory data analysis</li>
#     <li>Data analysis</li>
#     <li>Policy recommendations</li>
#   </ol>
#   <hr>
#
#   <!-- This is a comment -->
#
# </body>
# </html>

# %% [markdown]
# ## Web Scraping with `requests` and `BeautifulSoup`
#
# We will use `requests` and `BeautifulSoup` to access and scrape the content of [IMDB's homepage](https://www.imdb.com).
#
# ### What is `BeautifulSoup`?
#
# It is a Python library for pulling data out of HTML and XML files. It provides methods to navigate the document's tree structure that we discussed before and scrape its content.
#
# *Fun fact: The BeautifulSoup library was named after a Lewis Carroll poem of the same name in Alice’s Adventures in Wonderland. *
#
# ### A Pipeline Example
# <img src='scrape-pipeline.png' width="1024">

# %% [markdown]
# ## How do you figure out what information to scrape?
#
# "Selectors" can be found using the “inspect web element” feature that is available in all modern browsers.
#
# In the google Chrome case, you can use Chrome DevTools.
#
# #### Chrome DevTools
#
# [Chrome DevTools](https://developers.google.com/web/tools/chrome-devtools/) is a set of web developer tools built directly into the Google Chrome browser. DevTools can help you view and edit web pages. We will use Chrome's tool to inspect an HTML page and find which elements correspond to the data we might want to scrape.
#
# #### Short exercise
# To get some experience with the HTML page structure, we will search and locate elements in [IMDB](https://www.imdb.com/).
#
# **Tip**: Hit *Command+Option+C* (Mac) or *Control+Shift+C* (Windows, Linux) to access the elements panel. Or right-click and choose “Inspect”
#
# Typically, it doesn't matter which browser you use.
#
# #### Tasks (we will do them together)
# * Find the _Sign in_ button
# * Find the box containing the _Up next_
# * Locate one of the photos/videos in the main section of the page.
# * What is the size of the main photo?

# %% [markdown]
# # Let's get to Scraping!

# %%
# !pip install bs4

# %%
# Import necessary libraries
import requests 
import numpy as np
import pandas as pd
import pprint
from bs4 import BeautifulSoup  #this is the spell that helps you read tags

# %%
# IMDB's homepage
imdb_url = 'https://www.imdb.com'

# Use requests to retrieve data from a given URL
imdb_response = requests.get(imdb_url)

# Parse the whole HTML page using BeautifulSoup
imdb_soup = BeautifulSoup(imdb_response.text, 'html.parser')

# Title of the parsed page
imdb_soup.title
# Out:
# <title data-react-helmet="true">IMDb: Ratings, Reviews, and Where to Watch the Best Movies &amp; TV Shows</title>

# %% [markdown]
# See how the tags `<title>` identify what you are looking for

# %%
# We can also get it without the HTML tags
imdb_soup.title.string
# Out:
# 'IMDb: Ratings, Reviews, and Where to Watch the Best Movies & TV Shows'

# %%
# we can inspect what the html code looks like
#and can manually see title, but really, we just want to extract the information relevant to our data collection process
print(imdb_soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/">
#  <head>
#   <script>
#    if (typeof uet == 'function') {
#                 uet("bb", "LoadTitle", {wb: 1});
#             }
#   </script>
#   <title data-react-helmet="true">
#    IMDb: Ratings, Reviews, and Where to Watch the Best Movies &amp; TV Shows
#   </title>
#   <script>
#    if (typeof uet == 'function') {
#                 uet("be", "LoadTitle", {wb: 1});
#             }
#   </script>
#   <script>
#    if (typeof uex == 'function') {
#                 uex("ld", "LoadTitle", {wb: 1});
#             }
#   </script>
#   <meta content="text/html; charset=utf-8" data-react-helmet="true" http-equiv="Content-Type"/>
#   <meta charset="utf-8" data-react-helmet="true"/>
#   <meta content="width=device-width, initial-scale=1.0" data-react-helmet="true" name="viewport"/>
#   <meta content="http://www.imdb.com/" data-react-helmet="true" property="og:url"/>
#   <meta content="IMDb is the world's most popular and authoritative source for movie, TV and celebrity content. Find ratings and reviews for the newest movie and TV shows. Get personalized recommendations, and learn where to watch across hundreds of streaming providers." data-react-helmet="true" name="description"/>
#   <meta content="-41chk8SjktlW5suRZ4hSSArjxmVu7i89S2ljNh8_a8" data-react-helmet="true" name="google-site-verification"/>
#   <meta content="https://m.media-amazon.com/images/G/01/imdb/images-ANDW73HA/imdb_fb_logo._CB1542065250_.png" data-react-helmet="true" property="og:image"/>
#   <meta content="115109575169727" data-react-helmet="true" property="fb:app_id"/>
#   <meta content="IMDb: Ratings, Reviews, and Where to Watch the Best Movies &amp; TV Shows" data-react-helmet="true" property="og:title"/>
#   <meta content="IMDb" data-react-helmet="true" property="og:site_name"/>
#   <meta content="IMDb: Ratings, Reviews, and Where to Watch the Best Movies &amp; TV Shows" data-react-helmet="true" name="title"/>
#   <meta content="IMDb is the world's most popular and authoritative source for movie, TV and celebrity content. Find ratings and reviews for the newest movie and TV shows. Get personalized recommendations, and learn where to watch across hundreds of streaming providers." data-react-helmet="true" property="og:description"/>
#   <script>
#    if (typeof uet == 'function') {
#                 uet("bb", "LoadIcons", {wb: 1});
#             }
#   </script>
#   <link data-react-helmet="true" href="https://ia.media-imdb.com/images/G/01/imdbads/css/responsive-styles-4290204852._CB408869472_.css" rel="stylesheet"/>
#   <link data-react-helmet="true" href="https://www.imdb.com/" rel="canonical"/>
#   <link data-react-helmet="true" href="https://m.media-amazon.com/images/G/01/imdb/images-ANDW73HA/favicon_desktop_32x32._CB1582158068_.png" rel="icon" sizes="32x32"/>
#   <link data-react-helmet="true" href="https://m.media-amazon.com/images/G/01/imdb/images-ANDW73HA/favicon_iPad_retina_167x167._CB1582158068_.png" rel="icon" sizes="167x167"/>
#   <link data-react-helmet="true" href="https://m.media-amazon.com/images/G/01/imdb/images-ANDW73HA/favicon_iPhone_retina_180x180._CB1582158069_.png" rel="icon" sizes="180x180"/>
#   <link data-react-helmet="true" href="https://m.media-amazon.com/images/G/01/imdb/images-ANDW73HA/apple-touch-icon-mobile._CB479963088_.png" rel="apple-touch-icon"/>
#   <link data-react-helmet="true" href="https://m.media-amazon.com/images/G/01/imdb/images-ANDW73HA/apple-touch-icon-mobile-76x76._CB479962152_.png" rel="apple-touch-icon" sizes="76x76"/>
#   <link data-react-helmet="true" href="https://m.media-amazon.com/images/G/01/imdb/images-ANDW73HA/apple-touch-icon-mobile-120x120._CB479963088_.png" rel="apple-touch-icon" sizes="120x120"/>
#   <link data-react-helmet="true" href="https://m.media-amazon.com/images/G/01/imdb/images-ANDW73HA/apple-touch-icon-web-152x152._CB479963088_.png" rel="apple-touch-icon" sizes="152x152"/>
#   <link data-react-helmet="true" href="https://m.media-amazon.com/images/G/01/imdb/images-ANDW73HA/android-mobile-196x196._CB479962153_.png" rel="shortcut icon" sizes="196x196"/>
#   <script>
#    if (typeof uet == 'function') {
#                 uet("be", "LoadIcons", {wb: 1});
#             }
#   </script>
#   <script>
#    if (typeof uex == 'function') {
#                 uex("ld", "LoadIcons", {wb: 1});
#             }
#   </script>
#   <script>
#    if (typeof uet == 'function') {
#                 uet("bb", "LoadCSS", {wb: 1});
#             }
#   </script>
#   <script>
#    if (typeof uet == 'function') {
#                 uet("be", "LoadCSS", {wb: 1});
#             }
#   </script>
#   <script>
#    if (typeof uex == 'function') {
#                 uex("ld", "LoadCSS", {wb: 1});
#             }
#   </script>
#   <script>
#    if (typeof uet == 'function') {
#                 uet("bb", "LoadHeaderJS", {wb: 1});
#             }
#   </script>
#   <script data-react-helmet="true">
#    window.ads_js_start = new Date().getTime();
# var imdbads = imdbads || {}; imdbads.cmd = imdbads.cmd || [];
#   </script>
#   <script data-react-helmet="true">
#    !function a(b,c,d){function e(g,h){if(!c[g]){if(!b[g]){var i="function"==typeof require&&require;if(!h&&i)return i(g,!0);if(f)return f(g,!0);var j=new Error("Cannot find module '"+g+"'");throw j.code="MODULE_NOT_FOUND",j}var k=c[g]={exports:{}};b[g][0].call(k.exports,function(a){var c=b[g][1][a];return e(c?c:a)},k,k.exports,a,b,c,d)}return c[g].exports}for(var f="function"==typeof require&&require,g=0;g<d.length;g++)e(d[g]);return e}({1:[function(a,b,c){"use strict";a(2)},{2:2}],2:[function(a,b,c){"use strict";!function(){var a,b,c=function(a){return"[object Array]"===Object.prototype.toString.call(a)},d=function(a,b){for(var c=0;c<a.length;c++)c in a&&b.call(null,a[c],c)},e=[],f=!1,g=!1,h=function(){var a=[],b=[],c={};return d(e,function(e){var f="";d(e.dartsite.split("/"),function(b){""!==b&&(b in c||(c[b]=a.length,a.push(b)),f+="/"+c[b])}),b.push(f)}),{iu_parts:a,enc_prev_ius:b}},i=function(){var a=[];return d(e,function(b){var c=[];d(b.sizes,function(a){c.push(a.join("x"))}),a.push(c.join("|"))}),a},j=function(){var a=[];return d(e,function(b){a.push(k(b.targeting))}),a.join("|")},k=function(a,b){var c,d=[];for(var e in a){c=[];for(var f=0;f<a[e].length;f++)c.push(encodeURIComponent(a[e][f]));b?d.push(e+"="+encodeURIComponent(c.join(","))):d.push(e+"="+c.join(","))}return d.join("&")},l=function(){var a=+new Date;g||document.readyState&&"loaded"!==document.readyState||(g=!0,f&&imdbads.cmd.push(function(){for(var b=0;b<e.length;b++)generic.monitoring.record_metric(e[b].name+".fail",csm.duration(a))}))};window.tinygpt={define_slot:function(a,b,c,d){e.push({dartsite:a.replace(/\/$/,""),sizes:b,name:c,targeting:d})},set_targeting:function(b){a=b},callback:function(a){var c,d,f={},g=+new Date;try{for(var h=0;h<e.length;h++)c=e[h].dartsite,d=e[h].name,a[h][c]?f[d]=a[h][c]:window.console&&console.error&&console.error("Unable to correlate GPT response for "+d);imdbads.cmd.push(function(){for(var a=0;a<e.length;a++)ad_utils.slot_events.trigger(e[a].name,"request",{timestamp:b}),ad_utils.slot_events.trigger(e[a].name,"tagdeliver",{timestamp:g});ad_utils.gpt.handle_response(f)})}catch(i){window.console&&console.error&&console.error("Exception in GPT callback: "+i.message)}},send:function(){var d,g,m=[],n=function(a,b){c(b)&&(b=b.join(",")),b&&m.push(a+"="+encodeURIComponent(""+b))};if(0===e.length)return void tinygpt.callback({});n("gdfp_req","1"),n("correlator",Math.floor(4503599627370496*Math.random())),n("output","json_html"),n("callback","tinygpt.callback"),n("impl","fifs"),n("json_a","1");var o=h();n("iu_parts",o.iu_parts),n("enc_prev_ius",o.enc_prev_ius),n("prev_iu_szs",i()),n("prev_scp",j()),n("cust_params",k(a,!0)),d=document.createElement("script"),g=document.getElementsByTagName("script")[0],d.async=!0,d.type="text/javascript",d.src="http://pubads.g.doubleclick.net/gampad/ads?"+m.join("&"),d.id="tinygpt",d.onload=d.onerror=d.onreadystatechange=l,f=!0,g.parentNode.insertBefore(d,g),b=+new Date}}}()},{}]},{},[1]);
#   </script>
#   <script data-react-helmet="true" id="ads_tarnhelm" src="https://ia.media-imdb.com/images/G/01/imdbads/js/collections/tarnhelm-2462982807._CB403294465_.js">
#   </script>
#   <script data-react-helmet="true" id="ads_doWithAds">
#    doWithAds = function(inside, failureMessage){
# if ('consoleLog' in window &&
# 'generic' in window &&
# 'ad_utils' in window &&
# 'custom' in window &&
# 'monitoring' in generic &&
# 'document_is_ready' in generic) {
# try{
# inside.call(this);
# }catch(e) {
# if ( window.ueLogError ) {
# if(typeof failureMessage !== 'undefined'){
# e.message = failureMessage;
# }
# e.attribution = "Advertising";
# e.logLevel = "ERROR";
# ueLogError(e);
# }
# if( (document.location.hash.match('debug=1')) &&
# (typeof failureMessage !== 'undefined') ){
# console.error(failureMessage);
# }
# }
# } else {
# if( (document.location.hash.match('debug=1')) &&
# (typeof failureMessage !== 'undefined') ){
# console.error(failureMessage);
# }
# }
# };
#   </script>
#   <script data-react-helmet="true" id="ads_monitoring_setup">
#    doWithAds(function(){
# generic.monitoring.set_forester_info("homepage");
# generic.monitoring.set_twilight_info(
# "homepage",
# "US",
# "1affc1ec114e7bb250d1c553094f29c2bb48c686",
# "2020-10-08T15%3A25%3A10GMT",
# "https://s.media-imdb.com/twilight/?",
# "consumer");
# generic.monitoring.start_timing("page_load");
# generic.seconds_to_midnight = 56090;
# generic.days_to_midnight = 0.649189829826355;
# },"Generic not defined, skipping monitoring setup.");
#   </script>
#   <script data-react-helmet="true" src="https://images-na.ssl-images-amazon.com/images/G/01/ape/sf/desktop/DAsf-1.50.996289c._V428881811_.js">
#   </script>
#   <script data-react-helmet="true" id="ads_safeframe_setup">
#    doWithAds(function(){
# if (typeof DAsf != 'undefined' && typeof DAsf.registerCustomMessageListener === 'function') {
# DAsf.registerCustomMessageListener('updateAdDetails', window.ad_utils.update_ad_details);
# DAsf.registerCustomMessageListener('setPartner', window.ad_utils.set_partner);
# DAsf.registerCustomMessageListener('adFeedback', window.ad_utils.show_ad_feedback);
# DAsf.registerCustomMessageListener('sendMetrics', window.generic.monitoring.update_sf_slot_metrics);
# DAsf.registerCustomMessageListener('expand', window.ad_utils.expand_overlay);
# DAsf.registerCustomMessageListener('collapse', window.ad_utils.collapse_overlay);
# }
# },"ads js missing, skipping safeframe setup.");
#   </script>
#   <script data-react-helmet="true" id="ads_general_setup">
#    doWithAds(function(){
# generic.monitoring.record_metric("ads_js_request_to_done", (new Date().getTime()) - window.ads_js_start);
# generic.send_csm_head_metrics && generic.send_csm_head_metrics();
# ad_utils.set_slots_on_page({ 'inline20':1, 'sis_pixel':1, 'inline40':1 });
# custom.full_page.data_url = "https://ia.media-imdb.com/images/G/01/imdbads/js/graffiti_data-14866052._CB426574947_.js";
# consoleLog('advertising initialized','ads');
# },"ads js missing, skipping general setup.");
#   </script>
#   <script data-react-helmet="true">
#    doWithAds(function() { ad_utils.ads_header.done(); });
#   </script>
#   <script>
#    if (typeof uet == 'function') {
#                 uet("be", "LoadHeaderJS", {wb: 1});
#             }
#   </script>
#   <script>
#    if (typeof uex == 'function') {
#                 uex("ld", "LoadHeaderJS", {wb: 1});
#             }
#   </script>
#  </head>
#  <body>
#   <link href="https://m.media-amazon.com/images/I/81+-6U9ydGL.css" rel="stylesheet"/>
#   <link href="https://m.media-amazon.com/images/I/41MmRWn5ioL.css" rel="stylesheet"/>
#   <link href="https://m.media-amazon.com/images/I/61wMwzGBRhL.css" rel="stylesheet"/>
#   <link href="https://m.media-amazon.com/images/I/11dmBXKyrKL.css" rel="stylesheet"/>
#   <link href="https://m.media-amazon.com/images/I/01ozJiywSwL.css" rel="stylesheet"/>
#   <link href="https://m.media-amazon.com/images/I/31Ek+dUQghL.css" rel="stylesheet"/>
#   <link href="https://m.media-amazon.com/images/I/21n-h8v9lvL.css" rel="stylesheet"/>
#   <link href="https://m.media-amazon.com/images/I/01fccOaYFAL.css" rel="stylesheet"/>
#   <link href="https://m.media-amazon.com/images/I/11PxGghTGDL.css" rel="stylesheet"/>
#   <link href="https://m.media-amazon.com/images/I/11nIqncIA5L.css" rel="stylesheet"/>
#   <link href="https://m.media-amazon.com/images/I/11f0y6lH1oL.css" rel="stylesheet"/>
#   <link href="https://m.media-amazon.com/images/I/110AAKLZdVL.css" rel="stylesheet"/>
#   <link href="https://m.media-amazon.com/images/I/01mQW+TCOoL.css" rel="stylesheet"/>
#   <link href="https://m.media-amazon.com/images/I/21qauJZavyL.css" rel="stylesheet"/>
#   <link href="https://m.media-amazon.com/images/I/11jPo+kvoQL.css" rel="stylesheet"/>
#   <link href="https://m.media-amazon.com/images/I/01FmGt3xtNL.css" rel="stylesheet"/>
#   <link href="https://m.media-amazon.com/images/I/31MNUBxsB+L.css" rel="stylesheet"/>
#   <link href="https://m.media-amazon.com/images/I/01RFmPUCXJL.css" rel="stylesheet"/>
#   <link href="https://m.media-amazon.com/images/I/0170WD9ZUXL.css" rel="stylesheet"/>
#   <link href="https://m.media-amazon.com/images/I/01Qh2AncPmL.css" rel="stylesheet"/>
#   <link href="https://m.media-amazon.com/images/I/0116OiXBkvL.css" rel="stylesheet"/>
#   <style data-styled="ktEnXV bmFfZH gUiXxr eGXWKr kgjqmD iQWAlG fjLstn ijHKQE dYzJro jGFlLU bgzAeT gUgDEj iWlUOU fCFkwz sVyDb hAUoSP hOwCdO ibWJpR jAJuqP jIbbnv iCQWEu bQZNWZ elgZIA iTyDTb kPnwgD dPmROd jvQohW VrgqF dRtPwF jTnlGZ behHdd kWtTrU cwIihd iLBqtX cqtngf dkZsig jTzUIl ktzslD cdLJQv gFEKSx cxloje cjCDsL jZASpf eYwewV cFSMOE kMejoQ dsVNKx dKrdIU duIESy hcwbey geYfso dnUagO jsWsMV CwIFp dwiBZU iAixTV iIQGKv cNKMWL drvZQv eXRXJ kUrTCY kZmcOc hJHHUo duWEHC cTXhQE iZWuhv eDdnBe dqfMEd jjDLdw" data-styled-version="4.3.2">
#    /* sc-component-id: sc-bdVaJa */
# .iWlUOU{-webkit-flex-shrink:0;-ms-flex-negative:0;flex-shrink:0;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;margin-left:0.25rem;margin-right:auto;-webkit-order:1;-ms-flex-order:1;order:1;position:relative;} @media screen and (min-width:1024px){.iWlUOU{margin-left:auto;margin-right:0.5rem;-webkit-order:0;-ms-flex-order:0;order:0;padding-left:0;}} @media (hover:hover) and (pointer:fine){.iWlUOU:focus{outline:1px dashed currentColor;}.iWlUOU:focus:active{outline:0;}.iWlUOU:before,.iWlUOU:after{border-radius:10%;bottom:0;content:'';height:100%;left:0;margin:auto;opacity:0;position:absolute;right:0;top:0;-webkit-transition:opacity .2s cubic-bezier(1,1,1,1);transition:opacity .2s cubic-bezier(1,1,1,1);width:100%;}}
# /* sc-component-id: sc-bZQynM */
# .jIbbnv li:first-child > ._3GpC-Bj8birceXgWSkFbpC{border-top:none;}
# /* sc-component-id: sc-gzVnrw */
# .sVyDb{position:relative;} .sVyDb.navbar__flyout__text-button-after-mobile,.sVyDb .navbar__flyout__text-button-after-mobile{display:none;} .sVyDb .navbar__flyout__text-button-after-mobile > div{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;} .sVyDb .navbar__flyout--menu{top:100%;position:absolute;margin-top:.25rem;} .sVyDb.sVyDb.navbar__flyout--positionLeft .navbar__flyout--menu{left:0;right:auto;} @media screen and (min-width:600px){.sVyDb.navbar__flyout--breakpoint-m .navbar__flyout__icon-on-mobile{display:none;}.sVyDb.navbar__flyout--breakpoint-m .navbar__flyout__text-button-after-mobile{display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;}} @media screen and (min-width:1024px){.sVyDb.navbar__flyout--breakpoint-l .navbar__flyout__icon-on-mobile{display:none;}.sVyDb.navbar__flyout--breakpoint-l .navbar__flyout__text-button-after-mobile{display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;}} @media screen and (min-width:1280px){.sVyDb.navbar__flyout--breakpoint-xl .navbar__flyout__icon-on-mobile{display:none;}.sVyDb.navbar__flyout--breakpoint-xl .navbar__flyout__text-button-after-mobile{display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;}} .sVyDb .navbar__flyout__button-pointer{-webkit-transition:-webkit-transform 0.2s;-webkit-transition:transform 0.2s;transition:transform 0.2s;-webkit-transform:rotateX(0);-ms-transform:rotateX(0);transform:rotateX(0);} .sVyDb.navbar__flyout--isVisible .navbar__flyout__button-pointer{-webkit-transform:rotateX(180deg);-ms-transform:rotateX(180deg);transform:rotateX(180deg);}
# /* sc-component-id: sc-htoDjs */
# .jAJuqP .search-category-selector__opener{border-radius:2px 0 0 2px;padding:0 0 0 0.5rem;min-height:32px;height:20px;border-right:1px solid rgba(0,0,0,0.3);} .jAJuqP _1xTnkpad08eEWkqotpqi4r{cursor:pointer;}
# /* sc-component-id: sc-dnqmqq */
# .ibWJpR{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-flex:1;-webkit-flex-grow:1;-ms-flex-positive:1;flex-grow:1;margin:0;padding:0;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;} @media screen and (min-width:600px){.ibWJpR{-webkit-transition:border 0.2s,background-color 0.2s,box-shadow 0.2s;transition:border 0.2s,background-color 0.2s,box-shadow 0.2s;}} .ibWJpR .nav-search__search-input-container{width:100%;padding-right:3.5rem;} .ibWJpR ._2wo2z_hfPCHWGjZvUGi_f1{position:absolute;right:.35rem;min-width:2rem;cursor:pointer;top:.35rem;-webkit-transition:all 0.2s;transition:all 0.2s;} @media screen and (min-width:600px){.ibWJpR._34OlxISln9ojnodo9-xSUP ._2wo2z_hfPCHWGjZvUGi_f1{background:transparent;opacity:1;}} .ibWJpR .imdb-header-search__input{background:transparent;-webkit-box-flex:1;-webkit-flex-grow:1;-ms-flex-positive:1;flex-grow:1;outline:none;padding:1rem 1rem 1rem .75rem;width:100%;} @media screen and (min-width:600px){.ibWJpR .imdb-header-search__input{padding:.375em 0 .375rem .5rem;}} .ibWJpR .imdb-header-search__input::-ms-clear{display:none;}
# /* sc-component-id: sc-iwsKbI */
# .hAUoSP{-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;left:0;margin:0;min-height:3.5rem;opacity:0;-webkit-transform:translateY(-10px);-ms-transform:translateY(-10px);transform:translateY(-10px);-webkit-transition:none;transition:none;-webkit-order:3;-ms-flex-order:3;order:3;pointer-events:none;position:absolute;top:0;visibility:hidden;width:100%;z-index:1;} .hAUoSP .imdb-header-search__state-closer{-webkit-transform:scale(0.5);-ms-transform:scale(0.5);transform:scale(0.5);-webkit-transition:-webkit-transform 0.2s 0.1s;-webkit-transition:transform 0.2s 0.1s;transition:transform 0.2s 0.1s;display:inline;margin:.25rem;position:absolute;right:0;top:0;} .hAUoSP .imdb-header-search__state,.hAUoSP .imdb-header-search__input,.hAUoSP .nav-search__search-submit{-moz-appearance:none;-webkit-appearance:none;-webkit-appearance:none;-moz-appearance:none;appearance:none;border:none;} @media screen and (min-width:600px){.hAUoSP{-webkit-box-flex:1;-webkit-flex-grow:1;-ms-flex-positive:1;flex-grow:1;margin:0 0.5rem;padding:0;min-height:2.25rem;-webkit-order:3;-ms-flex-order:3;order:3;opacity:1;visibility:visible;pointer-events:auto;position:relative;-webkit-transform:translateY(0);-ms-transform:translateY(0);transform:translateY(0);}.hAUoSP .imdb-header-search__state,.hAUoSP .nav-search__search-submit{padding:0;}.hAUoSP .nav-search__search-submit:focus{outline:var(--ipt-focus-outline-on-base);outline-offset:1px;}.hAUoSP .imdb-header-search__state-closer{display:none;}}
# /* sc-component-id: sc-gZMcBi */
# .iCQWEu{-webkit-transition:all 0.3s;transition:all 0.3s;opacity:1;-webkit-transform:scale(1);-ms-transform:scale(1);transform:scale(1);-webkit-order:3;-ms-flex-order:3;order:3;} @media screen and (min-width:600px){.iCQWEu{-webkit-order:3;-ms-flex-order:3;order:3;}.iCQWEu.imdb-header-search__state-opener{display:none;}}
# /* sc-component-id: sc-gqjmRU */
# .hOwCdO:checked ~ .nav-search__search-container{opacity:1;-webkit-transform:scale(1);-ms-transform:scale(1);transform:scale(1);-webkit-transition:opacity 0.2s,-webkit-transform 0.2s;-webkit-transition:opacity 0.2s,transform 0.2s;transition:opacity 0.2s,transform 0.2s;visibility:visible;pointer-events:auto;z-index:100;} .hOwCdO:checked ~ .nav-search__search-container .nav-search__search-select,.hOwCdO:checked ~ .nav-search__search-container .nav-search__search-submit{display:none;} .hOwCdO:checked ~ .nav-search__search-container .imdb-header-search__state-closer{-webkit-transform:scale(1);-ms-transform:scale(1);transform:scale(1);} .hOwCdO:checked ~ .nav-search__search-container ~ .sc-gZMcBi{-webkit-transform:scale(0.5);-ms-transform:scale(0.5);transform:scale(0.5);-webkit-transition:all 0.3s 0.3s;transition:all 0.3s 0.3s;opacity:0;}
# /* sc-component-id: sc-VigVT */
# .kgjqmD._1ju2aDBdVVFcPcrZPSlJvp{bottom:0;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;left:0;overflow:hidden;-webkit-perspective:70vh;-moz-perspective:70vh;-ms-perspective:70vh;perspective:70vh;pointer-events:none;position:fixed;right:0;top:0;visibility:hidden;z-index:100;} .kgjqmD .lyr9sTGxhvocRns_pOj2r{box-shadow:none;box-sizing:border-box;height:100%;overflow-x:hidden;overflow-y:auto;position:relative;-webkit-transform:translateX(calc(-100% - 36px));-ms-transform:translateX(calc(-100% - 36px));transform:translateX(calc(-100% - 36px));-webkit-transform-origin:right center;-ms-transform-origin:right center;transform-origin:right center;-webkit-transition:all 0.3s,box-shadow 0s;transition:all 0.3s,box-shadow 0s;width:280px;z-index:2;-webkit-overflow-scroll:touch;} .kgjqmD ._33DjoP1bQFTGjUsd6TDnRs{box-sizing:border-box;display:block;height:100%;left:0;opacity:0;position:absolute;top:0;-webkit-transition:opacity 0.3s;transition:opacity 0.3s;visibility:hidden;width:100%;will-change:opacity;z-index:1;} .kgjqmD ._1qi_bqG55RhaaowgrBUFki{-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;box-sizing:border-box;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:end;-webkit-justify-content:flex-end;-ms-flex-pack:end;justify-content:flex-end;min-height:3.5rem;margin-bottom:0.5rem;padding:0.25rem;} .kgjqmD .BoMErbIIt00tb_ZoTOWZv{-webkit-touch-callout:none;-webkit-tap-highlight-color:transparent;} ._3vqFsbtuHc7lRMf9zsPxus:checked ~ .kgjqmD._1ju2aDBdVVFcPcrZPSlJvp{pointer-events:auto;visibility:visible;} ._3vqFsbtuHc7lRMf9zsPxus:checked ~ .kgjqmD._1ju2aDBdVVFcPcrZPSlJvp > .lyr9sTGxhvocRns_pOj2r{-webkit-transform:translateX(0);-ms-transform:translateX(0);transform:translateX(0);box-shadow:0px 11px 15px -7px rgba(var(--ipt-baseAlt-rgb),0.2), 0px 24px 38px 3px rgba(var(--ipt-baseAlt-rgb),0.14), 0px 9px 46px 8px rgba(var(--ipt-baseAlt-rgb),0.12);} ._3vqFsbtuHc7lRMf9zsPxus:checked ~ .kgjqmD._1ju2aDBdVVFcPcrZPSlJvp > ._33DjoP1bQFTGjUsd6TDnRs{opacity:0.5;visibility:visible;} @media screen and (min-width:1024px){.kgjqmD .lyr9sTGxhvocRns_pOj2r{width:100%;-webkit-transform:translateY(calc(-100%));-ms-transform:translateY(calc(-100%));transform:translateY(calc(-100%));padding:2rem 0;}.kgjqmD ._1qi_bqG55RhaaowgrBUFki{background:none;max-width:1024px;margin:auto;-webkit-box-pack:justify;-webkit-justify-content:space-between;-ms-flex-pack:justify;justify-content:space-between;padding:0 1rem;}.kgjqmD .KwBCkDEj0GWPCoK4HmZ2T{max-width:1024px;margin:auto;}.kgjqmD ._31OEZk7-hOsGgr6aTOS5te{display:inline;}}
# /* sc-component-id: sc-jTzLTM */
# .fjLstn .ipc-icon{opacity:0.5;-webkit-transition:opacity 0.2s;transition:opacity 0.2s;} .fjLstn:hover .ipc-icon{opacity:1;} @media screen and (max-width:479px){.fjLstn.nav-link--hideXS{display:none;}} @media screen and (min-width:480px) and (max-width:599px){.fjLstn.nav-link--hideS{display:none;}} @media screen and (min-width:600px) and (max-width:1023px){.fjLstn.nav-link--hideM{display:none;}} @media screen and (min-width:1024px) and (max-width:1279px){.fjLstn.nav-link--hideL{display:none;}} @media screen and (min-width:1280px){.fjLstn.nav-link--hideXL{display:none;}}
# /* sc-component-id: sc-fjdhpX */
# .dYzJro ._1UO7JWXJx2A3lPt87JY0Gh{cursor:pointer;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;border-top:1px solid transparent;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:justify;-webkit-justify-content:space-between;-ms-flex-pack:justify;justify-content:space-between;height:3rem;margin:0;padding:0 1rem;-webkit-transition:color 0.1s ease-in,border-color 0.1s ease-in,opacity 0.12s ease-in;transition:color 0.1s ease-in,border-color 0.1s ease-in,opacity 0.12s ease-in;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;} .dYzJro ._1UO7JWXJx2A3lPt87JY0Gh:focus{outline:var(--ipt-focus-outline-on-baseAlt);outline-offset:1px;} .dYzJro ._2Iv_l4vJVkTcKsXSsnjoyl{padding-right:0.75rem;} .dYzJro ._3ljuaKnLgmSdYVv9u-R2kl{-webkit-box-flex:1;-webkit-flex-grow:1;-ms-flex-positive:1;flex-grow:1;overflow:hidden;padding-right:0.75rem;text-overflow:ellipsis;white-space:nowrap;} .dYzJro ._3eshWnjV18LJcWXsSl9YJv{-webkit-transform:rotate(90deg);-ms-transform:rotate(90deg);transform:rotate(90deg);} .dYzJro ._2Iv_l4vJVkTcKsXSsnjoyl,.dYzJro ._3eshWnjV18LJcWXsSl9YJv{opacity:0.5;-webkit-transition:all 0.2s;transition:all 0.2s;} .dYzJro ._1UO7JWXJx2A3lPt87JY0Gh:focus ._3eshWnjV18LJcWXsSl9YJv,.dYzJro ._1UO7JWXJx2A3lPt87JY0Gh:hover ._3eshWnjV18LJcWXsSl9YJv,.dYzJro ._1UO7JWXJx2A3lPt87JY0Gh:focus ._2Iv_l4vJVkTcKsXSsnjoyl,.dYzJro ._1UO7JWXJx2A3lPt87JY0Gh:hover ._2Iv_l4vJVkTcKsXSsnjoyl{opacity:1;} .dYzJro ._3ugJBFJR4_oBad38XOic2A{overflow:hidden;border-bottom:1px solid transparent;-webkit-transition:border-color 0.1s ease-in,height 0.2s;transition:border-color 0.1s ease-in,height 0.2s;} .dYzJro ._16jTCq9eBU0A38SFBAoU8k:checked ~ span ._1UO7JWXJx2A3lPt87JY0Gh ._2Iv_l4vJVkTcKsXSsnjoyl{opacity:1;} .dYzJro ._16jTCq9eBU0A38SFBAoU8k:checked ~ span ._1UO7JWXJx2A3lPt87JY0Gh ._3eshWnjV18LJcWXsSl9YJv{-webkit-transform:rotate(-90deg);-ms-transform:rotate(-90deg);transform:rotate(-90deg);} .dYzJro ._16jTCq9eBU0A38SFBAoU8k:checked ~ span ._3ugJBFJR4_oBad38XOic2A{display:block;} .dYzJro:nth-of-type(1) ._1UO7JWXJx2A3lPt87JY0Gh{border-top:none;} @media screen and (min-width:1024px){.dYzJro.noMarginItem ._1UO7JWXJx2A3lPt87JY0Gh{margin-top:0;}} @media screen and (min-width:1024px){.dYzJro{-webkit-flex-basis:33%;-ms-flex-preferred-size:33%;flex-basis:33%;}.dYzJro ._1UO7JWXJx2A3lPt87JY0Gh{pointer-events:none;margin-top:1.5rem;height:3rem;border:none;}.dYzJro ._16jTCq9eBU0A38SFBAoU8k:checked ~ ._299G6wcz6LCpY_QFQJtc76 ._1UO7JWXJx2A3lPt87JY0Gh ._3ljuaKnLgmSdYVv9u-R2kl{color:inherit;}.dYzJro ._3ugJBFJR4_oBad38XOic2A{visibility:inherit;height:auto !important;border:0;}.dYzJro ._3eshWnjV18LJcWXsSl9YJv{display:none;}.dYzJro ._2Iv_l4vJVkTcKsXSsnjoyl{color:var(--ipt-on-baseAlt-accent1-color);opacity:1;}.dYzJro .ipc-list__item{height:2rem;}.dYzJro .ipc-list--baseAlt .ipc-list__item:hover{background:none;-webkit-text-decoration:underline;text-decoration:underline;}} @media screen and (max-width:479px){.dYzJro._1K0S44SUv8s7pXTI-caWlb--hideXS{display:none;}} @media screen and (min-width:480px) and (max-width:599px){.dYzJro._1K0S44SUv8s7pXTI-caWlb--hideS{display:none;}} @media screen and (min-width:600px) and (max-width:1023px){.dYzJro._1K0S44SUv8s7pXTI-caWlb--hideM{display:none;}} @media screen and (min-width:1024px) and (max-width:1279px){.dYzJro._1K0S44SUv8s7pXTI-caWlb--hideL{display:none;}} @media screen and (min-width:1280px){.dYzJro._1K0S44SUv8s7pXTI-caWlb--hideXL{display:none;}}
# /* sc-component-id: sc-jzJRlG */
# @media screen and (min-width:1024px){.jGFlLU{-webkit-flex-basis:33%;-ms-flex-preferred-size:33%;flex-basis:33%;}}
# /* sc-component-id: sc-cSHVUG */
# @media screen and (min-width:1024px){.bgzAeT{-webkit-flex-basis:33%;-ms-flex-preferred-size:33%;flex-basis:33%;}}
# /* sc-component-id: sc-kAzzGY */
# .iQWAlG ._1bKcOWQ444SDYrHdrDfuVi{list-style:none;margin:0.5rem 0;opacity:0.2;} .iQWAlG ._2gsLsBPK0cn_jZtMaWl-cV{margin-bottom:3rem;margin-top:1.5rem;padding:1rem;height:auto;} @media screen and (min-width:1024px){.iQWAlG{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-wrap:wrap;-ms-flex-wrap:wrap;flex-wrap:wrap;}.iQWAlG ._3Z7jdw9w5CmgawYgX0UPK2{display:none;}.iQWAlG ._2gsLsBPK0cn_jZtMaWl-cV{-webkit-align-self:flex-start;-ms-flex-item-align:start;align-self:flex-start;display:none;}.iQWAlG:focus{outline:var(--ipt-focus-outline-on-baseAlt);outline-offset:1px;}}
# /* sc-component-id: sc-chPdSV */
# .ijHKQE{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;}
# /* sc-component-id: sc-kgoBCf */
# .gUgDEj{margin-top:.25rem;}
# /* sc-component-id: sc-kGXeez */
# .eGXWKr{-webkit-flex-shrink:0;-ms-flex-negative:0;flex-shrink:0;-webkit-order:0;-ms-flex-order:0;order:0;} .eGXWKr.desktop{display:none;} @media screen and (min-width:1024px){.eGXWKr{-webkit-order:1;-ms-flex-order:1;order:1;}.eGXWKr.mobile{display:none;}.eGXWKr.desktop{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;}}
# /* sc-component-id: sc-kpOJdX */
# .kPnwgD{-webkit-order:6;-ms-flex-order:6;order:6;} @media screen and (min-width:600px){.kPnwgD .navbar__user-menu__username-divider,.kPnwgD .navbar__user-menu__username{display:none;}} @media screen and (min-width:1024px){.kPnwgD{-webkit-order:7;-ms-flex-order:7;order:7;}} .kPnwgD .navbar__user-menu-toggle__button{padding-right:0.25rem;} .kPnwgD .navbar__user-name{max-width:160px;text-overflow:ellipsis;white-space:nowrap;overflow:hidden;}
# /* sc-component-id: sc-dxgOiQ */
# .fCFkwz{-webkit-order:2;-ms-flex-order:2;order:2;} @media screen and (min-width:1024px){.fCFkwz{-webkit-order:2;-ms-flex-order:2;order:2;}} .fCFkwz .navbar__imdb-tv--heading{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:justify;-webkit-justify-content:space-between;-ms-flex-pack:justify;justify-content:space-between;margin-bottom:0.5rem;} .fCFkwz .navbar__imdb-tv--heading-text{color:var(--ipt-on-baseAlt-textSecondary-color);font-size:1rem;margin:0;} .fCFkwz .navbar__imdb-tv--more-link{-webkit-text-decoration:none;text-decoration:none;} .fCFkwz .navbar__imdb-tv--more-link:hover{-webkit-text-decoration:underline;text-decoration:underline;} .fCFkwz .navbar__flyout--menu{padding:1rem;} .fCFkwz .navbar__imdb-tv--poster-container{margin:0 -0.5rem;} .fCFkwz .navbar__imdb-tv--poster-card{margin:0 0.5rem;padding-bottom:0;} .fCFkwz .navbar__imdb-tv--play-icon{height:3rem;width:3rem;} .fCFkwz .navbar__imdb-tv--toggle .ipc-button__text{-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;}
# /* sc-component-id: sc-ckVGcZ */
# .iTyDTb{-webkit-order:5;-ms-flex-order:5;order:5;display:none;} @media screen and (min-width:1024px){.iTyDTb{-webkit-order:6;-ms-flex-order:6;order:6;display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;}} .iTyDTb .imdb-header__watchlist-button-count{margin-left:0.5rem;background:var(--ipt-on-base-accent1-color);color:var(--ipt-on-accent1-color);padding:0 0.4rem;border-radius:10px;text-align:center;} .iTyDTb .ipc-button__text{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}
# /* sc-component-id: sc-jKJlTe */
# .bQZNWZ{-webkit-order:4;-ms-flex-order:4;order:4;} @media screen and (min-width:1024px){.bQZNWZ{-webkit-order:4;-ms-flex-order:4;order:4;}} .bQZNWZ .navbar__imdbpro-menu-toggle__name{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;} .bQZNWZ .navbar__imdbpro-content .navbar__flyout--menu{background-image:url(//m.media-amazon.com/images/G/01/imdb/images/navbar/imdbpro_navbar_menu_bg-3083451252._V_.png);background-size:cover;padding-left:17px;padding-bottom:25px;padding-top:25px;color:white;font-weight:bold;} .bQZNWZ .navbar__imdbpro-imdb-pro-ad{background-repeat:no-repeat;color:white;cursor:pointer;width:573px;overflow:hidden;border-radius:8px;left:initial;} .bQZNWZ .navbar__imdbpro-imdb-pro-ad .imdb-pro-ad__content,.bQZNWZ .navbar__imdbpro-imdb-pro-ad .imdb-pro-ad__image{display:inline-block;} .bQZNWZ .navbar__imdbpro-imdb-pro-ad .imdb-pro-ad__title{color:white;line-height:1.3em;margin-bottom:10px;} .bQZNWZ .navbar__imdbpro-imdb-pro-ad .imdb-pro-ad__line{cursor:inherit;} .bQZNWZ .navbar__imdbpro-imdb-pro-ad .imdb-pro-ad__link{display:inline-block;-webkit-text-decoration:none;text-decoration:none;vertical-align:middle;} .bQZNWZ .navbar__imdbpro-imdb-pro-ad .imdb-pro-ad__content,.bQZNWZ .navbar__imdbpro-imdb-pro-ad .imdb-pro-ad__image{vertical-align:top;} .bQZNWZ .navbar__imdbpro-imdb-pro-ad .imdb-pro-ad__content{font-family:'Arial';margin-left:15px;width:400px;} .bQZNWZ .navbar__imdbpro-imdb-pro-ad .imdb-pro-ad__content .imdb-pro-ad__line{display:list-item;font-size:12px;list-style-position:inside;list-style-type:disc;margin:0px;padding:.1rem 0;} .bQZNWZ .navbar__imdbpro-imdb-pro-ad .imdb-pro-ad__content .imdb-pro-ad__title{font-size:15px;} .bQZNWZ .navbar__imdbpro-imdb-pro-ad .imdb-pro-new__button{margin-top:15px;} .bQZNWZ .navbar__imdbpro-imdb-pro-ad .imdb-pro-new__button text{fill:#111111;font-size:13px;font-weight:normal;} .bQZNWZ .navbar__imdbpro-imdb-pro-ad .imdb-pro-new__button svg:hover rect,.bQZNWZ .navbar__imdbpro-imdb-pro-ad .imdb-pro-new__button text:hover rect{fill:#f7dd95;} .bQZNWZ .navbar__imdbpro-content .sub_nav{background-color:#f2f2f2;border-bottom-left-radius:10px;border-bottom-right-radius:10px;box-shadow:0 2px 5px rgba(0,0,0,0.6);color:#999;height:325px;} .bQZNWZ .navbar__imdbpro-content .sub_nav h5{color:#A58500;margin:20px 0 10px;position:relative;}
# /* sc-component-id: sc-eNQAEJ */
# .gUiXxr{display:none;}
# /* sc-component-id: sc-hMqMXs */
# .bmFfZH{padding:0.25rem;margin:0;position:relative;z-index:1000;min-height:3.5rem;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;width:100%;} .bmFfZH a{color:inherit;} .bmFfZH .navbar__inner{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:justify;-webkit-justify-content:space-between;-ms-flex-pack:justify;justify-content:space-between;width:100vw;margin:0;} @media screen and (min-width:600px){.bmFfZH .navbar__inner{padding:0 .75rem;}} @media screen and (min-width:1024px){.bmFfZH .navbar__inner{width:100%;margin:0 auto;}} .bmFfZH label{margin-bottom:0;}
# /* sc-component-id: sc-kEYyzF */
# .elgZIA{border:1px solid rgba(var(--ipt-on-baseAlt-rgb),.16);-webkit-order:5;-ms-flex-order:5;order:5;width:1px;height:2rem;margin:0 .5rem;} @media screen and (max-width:600px){.elgZIA{display:none;-webkit-order:7;-ms-flex-order:7;order:7;}}
# /* sc-component-id: sc-hSdWYo */
# .dPmROd{position:relative;}
# /* sc-component-id: sc-eHgmQL */
# .jvQohW{position:relative;}
# /* sc-component-id: TitlePosterWithPeekstyles__WithPeekStyledPosterComposition-sc-1ryjwsd-0 */
# .iLBqtX{cursor:pointer;}
# /* sc-component-id: SlideCaptionstyles__CaptionTextContainer-sc-8h388a-1 */
# .cjCDsL{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;min-width:0;-webkit-box-pack:space-around;-webkit-justify-content:space-around;-ms-flex-pack:space-around;justify-content:space-around;width:100%;}
# /* sc-component-id: SlideCaptionstyles__PlayIcon-sc-8h388a-5 */
# .gFEKSx{color:transparent;height:50px;margin:0 0 8px 0;width:50px;} @media (min-width:48em){.gFEKSx{height:72px;margin:0 16px 0 0;width:72px;}} .gFEKSx g{fill:#FFFFFF;}
# /* sc-component-id: SlideCaptionstyles__ActionIconContainer-sc-8h388a-7 */
# .cdLJQv{-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;}
# /* sc-component-id: SlideCaptionstyles__MobileRuntimeText-sc-8h388a-9 */
# .cxloje{display:block;font-family:var(--ipt-font-family);margin-left:1rem;} @media (min-width:48em){.cxloje{display:none;}}
# /* sc-component-id: SlideCaptionWithPeekstyle__WithPeekCaptionContainer-sc-1v8fw6-0 */
# .ktzslD{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:row;-ms-flex-direction:row;flex-direction:row;min-width:0;margin:16px 16px 0;position:absolute;bottom:0;right:0;left:177px;} @media (min-width:48em){.ktzslD{-webkit-align-items:flex-start;-webkit-box-align:flex-start;-ms-flex-align:flex-start;align-items:flex-start;}} @media (min-width:64em) and (max-width:79.9375em){.ktzslD{left:148px;}} @media (min-width:48em) and (max-width:63.9375em){.ktzslD{left:165px;}} @media (min-width:0em) and (max-width:47.9375em){.ktzslD{left:90px;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;}}
# /* sc-component-id: SlideCaptionWithPeekstyle__WithPeekCaptionHeading-sc-1v8fw6-1 */
# .jZASpf{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:flex-end;-webkit-box-align:flex-end;-ms-flex-align:flex-end;align-items:flex-end;} @media (min-width:0em) and (max-width:47.9375em){.jZASpf{font-size:1.25rem;}} @media (min-width:48em){.jZASpf{font-size:34px;line-height:40px;}}
# /* sc-component-id: SlideCaptionWithPeekstyle__WithPeekCaptionSubHeading-sc-1v8fw6-2 */
# .kMejoQ{font-family:var(--ipt-font-family);color:var(--ipt-on-baseAlt-textSecondary-color);font-weight:400;margin:0.25rem 0 0;overflow:hidden;text-align:start;text-overflow:ellipsis;white-space:nowrap;} @media (min-width:80em){.kMejoQ{font-size:24px;line-height:32px;}} @media (min-width:48em) and (max-width:79.9375em){.kMejoQ{font-size:20px;line-height:25px;}} @media (min-width:0em) and (max-width:47.9375em){.kMejoQ{font-size:14px;line-height:20px;}}
# /* sc-component-id: SlideCaptionWithPeekstyle__WithPeekCaptionHeadingText-sc-1v8fw6-3 */
# .eYwewV{font-family:var(--ipt-font-family);display:-webkit-box;-webkit-line-clamp:2;-webkit-box-orient:vertical;overflow:hidden;} @media (min-width:80em){.eYwewV{font-size:34px;line-height:40px;font-weight:400;max-height:80px;}} @media (min-width:48em) and (max-width:79.9375em){.eYwewV{font-size:24px;line-height:32px;font-weight:400;max-height:64px;}} @media (min-width:31.25em) and (max-width:47.9375em){.eYwewV{font-size:20px;line-height:25px;font-weight:400;max-height:50px;}} @media (min-width:0em) and (max-width:31.1875em){.eYwewV{font-size:16px;line-height:20px;font-weight:400;max-height:40px;}}
# /* sc-component-id: SlideCaptionWithPeekstyle__WithPeekRuntimeText-sc-1v8fw6-4 */
# .cFSMOE{color:var(--ipt-on-baseAlt-textSecondary-color);display:none;font-family:var(--ipt-font-family);font-size:1rem;line-height:28px;margin-left:2rem;} @media (min-width:48em){.cFSMOE{display:inline;font-size:1.25rem;-webkit-align-self:flex-end;-ms-flex-item-align:end;align-self:flex-end;}}
# /* sc-component-id: VideoSlatestyles__SlateImage-sc-13ee1gs-1 */
# .dkZsig{-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}
# /* sc-component-id: VideoSlateWithPeekstyles__WithPeekSlateContainer-oyjpyw-0 */
# .cqtngf{cursor:pointer;width:100% !important;text-align:left;padding-bottom:70px;position:relative;} .cqtngf.cqtngf{outline:none;} .cqtngf img{height:100%;} .cqtngf:hover .slide-caption-play-icon{color:transparent;} .cqtngf:hover .slide-caption-play-icon g{fill:#f5c518;fill:var(--ipt-on-baseAlt-accent1-color);}
# /* sc-component-id: AutorotateWithPeekSlidestyles__WithPeekSlideContainer-sc-85l9zx-0 */
# .behHdd{height:100%;}
# /* sc-component-id: AutorotateWithPeekSlidestyles__WithPeekDesktopContainer-sc-85l9zx-1 */
# .kWtTrU{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;position:relative;}
# /* sc-component-id: AutorotateWithPeekSlidestyles__WithPeekTitlePoster-sc-85l9zx-4 */
# .cwIihd{position:absolute !important;height:244px !important;width:165px !important;z-index:100;bottom:0;left:16px;} @media (min-width:64em) and (max-width:79.9375em){.cwIihd{height:195px !important;width:132px !important;}} @media (min-width:48em) and (max-width:63.9375em){.cwIihd{height:244px !important;width:165px !important;left:0;}} @media (min-width:0em) and (max-width:47.9375em){.cwIihd{height:140px !important;width:90px !important;left:0;}}
# /* sc-component-id: AutorotateWithPeekSlidestyles__WithPeekLazyRenderPlaceholder-sc-85l9zx-5 */
# .dsVNKx{width:100%;height:0;padding-top:56.25%;} @media (min-width:48em){.dsVNKx{padding-top:40.741%;}}
# /* sc-component-id: AutorotateWithPeekSlidestyles__WithPeekLazyRenderPlaceholderInner-sc-85l9zx-6 */
# .dKrdIU{position:absolute;top:0;left:0;bottom:0;right:0;}
# /* sc-component-id: AutorotateWithPeekSlidestyles__WithPeekContainerOverlay-sc-85l9zx-7 */
# .jTzUIl{background:linear-gradient( 180deg,transparent 0%,transparent 65%,rgba(0,0,0,0.7) 75%,rgba(0,0,0,1) 85%,rgba(0,0,0,1) 100% );background:linear-gradient( 180deg,transparent 0%,transparent 65%,rgba(var(--ipt-baseAlt-rgb),0.7) 77%,rgba(var(--ipt-baseAlt-rgb),1) 85%,rgba(var(--ipt-baseAlt-rgb),1) 100% );} @media (min-width:0em) and (max-width:31.1875em){.jTzUIl{background:linear-gradient( 180deg, transparent 0%, transparent 65%, rgba(0,0,0,0.7) 70%, rgba(0,0,0,1) 82%, rgba(0,0,0,1) 100% );background:linear-gradient( 180deg, transparent 0%, transparent 65%, rgba(var(--ipt-baseAlt-rgb),0.7) 70%, rgba(var(--ipt-baseAlt-rgb),1) 82%, rgba(var(--ipt-baseAlt-rgb),1) 100% );}}
# /* sc-component-id: AutorotatePeekstyle__EditorialColumnTitleContainer-z2dw6i-0 */
# .jsWsMV{height:52px;}
# /* sc-component-id: AutorotatePeekstyle__EditorialColumnContainer-z2dw6i-1 */
# .dwiBZU{height:444px;overflow:hidden;position:relative;} @media (min-width:64em) and (max-width:79.9375em){.dwiBZU{height:339px;}}
# /* sc-component-id: AutorotatePeekstyle__EditorialColumn-z2dw6i-2 */
# .iAixTV{position:absolute;top:0;bottom:0;left:0;right:0;overflow:hidden;background:linear-gradient( 0deg,transparent 0%,transparent 50%,rgba(18,18,18,0.7) 78%,rgba(18,18,18,1) 100% );} .iAixTV .editorial-slots{height:100%;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;top:-296px;position:absolute;width:100%;} @media (min-width:64em) and (max-width:79.9375em){.iAixTV .editorial-slots{top:-226px;}}
# /* sc-component-id: AutorotatePeekstyle__StyledPosterImage-z2dw6i-3 */
# .drvZQv{height:100%;width:100% !important;position:absolute !important;left:0;bottom:0;} .drvZQv img{height:100%;width:100%;}
# /* sc-component-id: AutorotatePeekstyle__EditorialSlot-z2dw6i-4 */
# .iIQGKv{padding:0 16px;-webkit-flex:0 0 148px;-ms-flex:0 0 148px;flex:0 0 148px;width:100%;position:relative;overflow:hidden;-webkit-transition:all 300ms;transition:all 300ms;} @media (min-width:64em) and (max-width:79.9375em){.iIQGKv{-webkit-flex:0 0 113px;-ms-flex:0 0 113px;flex:0 0 113px;}} .iIQGKv.transit-enter{-webkit-flex-basis:0;-ms-flex-preferred-size:0;flex-basis:0;} .iIQGKv.transit-enter-active{-webkit-flex-basis:148px;-ms-flex-preferred-size:148px;flex-basis:148px;} @media (min-width:64em) and (max-width:79.9375em){.iIQGKv.transit-enter-active{-webkit-flex-basis:113px;-ms-flex-preferred-size:113px;flex-basis:113px;}} .iIQGKv.transit-exit{-webkit-flex-basis:148px;-ms-flex-preferred-size:148px;flex-basis:148px;} @media (min-width:64em) and (max-width:79.9375em){.iIQGKv.transit-exit{-webkit-flex-basis:113px;-ms-flex-preferred-size:113px;flex-basis:113px;}} .iIQGKv.transit-exit-active{-webkit-flex-basis:0;-ms-flex-preferred-size:0;flex-basis:0;}
# /* sc-component-id: AutorotatePeekstyle__EditorialSlotPoster-z2dw6i-5 */
# .cNKMWL{position:absolute;left:16px;bottom:0;height:132px;width:88px;} @media (min-width:64em) and (max-width:79.9375em){.cNKMWL{height:97px;width:67px;}}
# /* sc-component-id: AutorotatePeekstyle__EditorialSlotDetails-z2dw6i-6 */
# .eXRXJ{position:absolute;top:0;right:0;left:112px;padding:18px 8px 0;overflow:hidden;-webkit-text-decoration:none;text-decoration:none;} .eXRXJ:hover{cursor:pointer;} .eXRXJ:hover .editorial-play-icon{color:transparent;} .eXRXJ:hover .editorial-play-icon g{fill:#f5c518;fill:var(--ipt-on-baseAlt-accent1-color);} @media (min-width:64em) and (max-width:79.9375em){.eXRXJ{left:83px;padding:16px 8px 0;}}
# /* sc-component-id: AutorotatePeekstyle__EditorialSlotDetail-z2dw6i-7 */
# .iZWuhv{-webkit-flex:0;-ms-flex:0;flex:0;width:100%;text-align:left;position:relative;}
# /* sc-component-id: AutorotatePeekstyle__EditorialSlotPlaybackDetail-z2dw6i-8 */
# .kUrTCY{-webkit-flex:0;-ms-flex:0;flex:0;width:100%;text-align:left;position:relative;margin-bottom:3px;}
# /* sc-component-id: AutorotatePeekstyle__EditorialSlotTitleDetail-z2dw6i-9 */
# .duWEHC{-webkit-flex:0;-ms-flex:0;flex:0;width:100%;text-align:left;position:relative;max-height:40px;}
# /* sc-component-id: AutorotatePeekstyle__EditorialSlotTitle-z2dw6i-10 */
# .cTXhQE{font-family:var(--ipt-font-family);color:var(--ipt-on-baseAlt-textSecondary-color);color:rgba(255,255,255,0.7);text-align:start;text-overflow:ellipsis;white-space:nowrap;overflow:hidden;font-size:16px;line-height:20px;width:100%;display:inline-block;color:#fff;color:var(--ipt-on-baseAlt-color);white-space:normal;display:-webkit-box;-webkit-line-clamp:2;-webkit-box-orient:vertical;max-height:40px;}
# /* sc-component-id: AutorotatePeekstyle__EditorialSlotSubtitle-z2dw6i-11 */
# .eDdnBe{font-family:var(--ipt-font-family);color:var(--ipt-on-baseAlt-textSecondary-color);color:rgba(255,255,255,0.7);text-align:start;text-overflow:ellipsis;white-space:nowrap;overflow:hidden;font-size:14px;line-height:20px;width:100%;display:inline-block;}
# /* sc-component-id: AutorotatePeekstyle__EditorialSlotRunTime-z2dw6i-12 */
# .hJHHUo{font-family:var(--ipt-font-family);color:var(--ipt-on-baseAlt-textSecondary-color);color:rgba(255,255,255,0.7);text-align:start;text-overflow:ellipsis;white-space:nowrap;overflow:hidden;font-size:14px;line-height:20px;display:inline-block;}
# /* sc-component-id: AutorotatePeekstyle__EditorialColumnTitle-z2dw6i-13 */
# .CwIFp{font-family:var(--ipt-font-family);color:var(--ipt-on-baseAlt-textSecondary-color);color:rgba(255,255,255,0.7);text-align:start;text-overflow:ellipsis;white-space:nowrap;overflow:hidden;font-size:20px;line-height:25px;font-weight:600;display:block;width:100%;padding:4px 0;color:#f5c518;color:rgb(245,197,24);color:var(--ipt-on-baseAlt-accent1-color);text-align:left;}
# /* sc-component-id: AutorotatePeekstyle__PlayIcon-z2dw6i-14 */
# .kZmcOc{color:transparent;height:32px;width:32px;margin-right:8px;} .kZmcOc g{fill:#FFFFFF;}
# /* sc-component-id: AutorotateWithPeekVideoCarouselstyles__WithPeekLayout-sc-1y0e8a1-0 */
# .VrgqF{position:relative;margin:8px auto;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;max-width:1280px;} @media (min-width:0em) and (max-width:63.9375em){.VrgqF{-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;}}
# /* sc-component-id: AutorotateWithPeekVideoCarouselstyles__WithPeekCarouselContainer-sc-1y0e8a1-1 */
# .dRtPwF{-webkit-flex:846;-ms-flex:846;flex:846;margin:0 8px;position:relative;overflow:hidden;} @media (min-width:64em) and (max-width:79.9375em){.dRtPwF{-webkit-flex:664;-ms-flex:664;flex:664;}} @media (min-width:0em) and (max-width:63.9375em){.dRtPwF{-webkit-flex:100%;-ms-flex:100%;flex:100%;}}
# /* sc-component-id: AutorotateWithPeekVideoCarouselstyles__WithPeekSideContainer-sc-1y0e8a1-2 */
# ...
#         </path>
#         <path d="M.467 9.907c-.248 0-.372-.124-.372-.37V.883C.095.635.219.51.467.51h.817c.125 0 .22.026.288.075.068.05.115.142.14.277l.111.686C3 .672 4.24.234 5.541.234c.904 0 1.592.238 2.063.713.471.476.707 1.165.707 2.066v6.524c0 .246-.124.37-.372.37H6.842c-.248 0-.372-.124-.372-.37V3.625c0-.655-.133-1.137-.4-1.445-.266-.31-.684-.464-1.254-.464-.979 0-1.94.315-2.881.946v6.875c0 .246-.125.37-.372.37H.467z" id="ftr__s">
#         </path>
#         <path d="M4.641 9.859c-1.462 0-2.58-.417-3.355-1.251C.51 7.774.124 6.566.124 4.985c0-1.569.4-2.783 1.2-3.641C2.121.486 3.252.055 4.714.055c.67 0 1.326.118 1.971.353.136.05.232.111.288.185.056.074.083.198.083.37v.501c0 .248-.08.37-.241.37-.062 0-.162-.018-.297-.055a5.488 5.488 0 0 0-1.544-.222c-1.04 0-1.79.262-2.248.787-.459.526-.688 1.362-.688 2.511v.241c0 1.124.232 1.949.697 2.474.465.525 1.198.788 2.203.788a5.98 5.98 0 0 0 1.672-.26c.136-.037.23-.056.279-.056.161 0 .242.124.242.371v.5c0 .162-.025.279-.075.353-.05.074-.148.142-.297.204-.608.259-1.314.389-2.119.389z" id="ftr__u">
#         </path>
#         <path d="M4.598 10.185c-1.413 0-2.516-.438-3.31-1.316C.497 7.992.1 6.769.1 5.199c0-1.555.397-2.773 1.19-3.65C2.082.673 3.185.235 4.598.235c1.412 0 2.515.438 3.308 1.316.793.876 1.19 2.094 1.19 3.65 0 1.569-.397 2.792-1.19 3.669-.793.878-1.896 1.316-3.308 1.316zm0-1.483c1.747 0 2.62-1.167 2.62-3.502 0-2.323-.873-3.484-2.62-3.484S1.977 2.877 1.977 5.2c0 2.335.874 3.502 2.62 3.502z" id="ftr__w">
#         </path>
#         <path d="M.396 9.907c-.248 0-.371-.124-.371-.37V.883C.025.635.148.51.396.51h.818a.49.49 0 0 1 .288.075c.068.05.115.142.14.277l.111.594C2.943.64 4.102.234 5.23.234c1.152 0 1.934.438 2.342 1.315C8.798.672 10.025.234 11.25.234c.856 0 1.512.24 1.971.722.458.482.688 1.168.688 2.057v6.524c0 .246-.124.37-.372.37h-1.097c-.248 0-.371-.124-.371-.37V3.533c0-.618-.119-1.075-.354-1.372-.235-.297-.607-.445-1.115-.445-.904 0-1.815.278-2.732.834.012.087.018.18.018.278v6.709c0 .246-.124.37-.372.37H6.42c-.249 0-.372-.124-.372-.37V3.533c0-.618-.118-1.075-.353-1.372-.235-.297-.608-.445-1.115-.445-.942 0-1.847.272-2.714.815v7.006c0 .246-.125.37-.372.37H.396z" id="ftr__y">
#         </path>
#         <path d="M.617 13.724c-.248 0-.371-.124-.371-.37V.882c0-.247.123-.37.371-.37h.818c.248 0 .39.123.428.37l.093.594C2.897.648 3.944.234 5.096.234c1.203 0 2.15.435 2.845 1.307.693.87 1.04 2.053 1.04 3.548 0 1.52-.365 2.736-1.096 3.65-.731.915-1.704 1.372-2.918 1.372-1.116 0-2.076-.365-2.881-1.094v4.337c0 .246-.125.37-.372.37H.617zM4.54 8.628c1.71 0 2.566-1.149 2.566-3.447 0-1.173-.208-2.044-.624-2.612-.415-.569-1.05-.853-1.904-.853-.88 0-1.711.284-2.491.853v5.17c.805.593 1.623.889 2.453.889z" id="ftr__A">
#         </path>
#         <path d="M2.971 10.148c-.88 0-1.583-.25-2.11-.75-.526-.501-.79-1.171-.79-2.011 0-.902.322-1.622.967-2.159.644-.538 1.512-.806 2.602-.806.694 0 1.475.104 2.342.315V3.513c0-.667-.15-1.136-.455-1.408-.304-.271-.821-.407-1.552-.407-.855 0-1.692.123-2.509.37-.285.087-.465.13-.54.13-.148 0-.223-.111-.223-.334v-.5c0-.16.025-.278.075-.352.05-.074.148-.142.297-.204.384-.173.87-.312 1.46-.417A9.991 9.991 0 0 1 4.29.234c1.177 0 2.045.244 2.603.731.557.489.836 1.233.836 2.233v6.338c0 .247-.125.37-.372.37h-.799c-.236 0-.372-.117-.41-.351l-.092-.612a5.09 5.09 0 0 1-1.478.89 4.4 4.4 0 0 1-1.608.315zm.446-1.39c.41 0 .836-.08 1.283-.241.446-.16.874-.395 1.282-.704v-1.89a8.403 8.403 0 0 0-1.97-.241c-1.4 0-2.1.537-2.1 1.612 0 .47.13.831.39 1.084.26.254.632.38 1.115.38z" id="ftr__C">
#         </path>
#         <path d="M.503 9.907c-.248 0-.371-.124-.371-.37V.883C.132.635.255.51.503.51h.818a.49.49 0 0 1 .288.075c.068.05.115.142.14.277l.111.686C3.037.672 4.277.234 5.578.234c.904 0 1.592.238 2.063.713.47.476.706 1.165.706 2.066v6.524c0 .246-.123.37-.371.37H6.879c-.248 0-.372-.124-.372-.37V3.625c0-.655-.133-1.137-.4-1.445-.266-.31-.684-.464-1.254-.464-.98 0-1.94.315-2.882.946v6.875c0 .246-.124.37-.371.37H.503z" id="ftr__E">
#         </path>
#         <path d="M1.988 13.443c-.397 0-.75-.043-1.059-.13-.15-.037-.251-.1-.307-.185a.684.684 0 0 1-.084-.37v-.483c0-.234.093-.352.28-.352.06 0 .154.013.278.037.124.025.291.037.502.037.459 0 .82-.114 1.087-.343.266-.228.505-.633.716-1.213l.353-.945L.167.675C.08.465.037.316.037.23c0-.149.086-.222.26-.222h1.115c.198 0 .334.03.409.093.075.062.148.197.223.407l2.602 7.19 2.51-7.19c.074-.21.148-.345.222-.407.075-.062.211-.093.41-.093h1.04c.174 0 .261.073.261.222 0 .086-.044.235-.13.445l-4.09 10.377c-.334.853-.725 1.464-1.17 1.835-.446.37-1.017.556-1.711.556z" id="ftr__G">
#         </path>
#        </defs>
#        <g fill="none" fill-rule="evenodd">
#         <g transform="translate(31.496 11.553)">
#          <mask fill="currentColor" id="ftr__b">
#           <use xlink:href="#ftr__a">
#           </use>
#          </mask>
#          <path d="M.04 6.088h26.91V.04H.04z" fill="currentColor" mask="url(#ftr__b)">
#          </path>
#         </g>
#         <g transform="translate(55.433 10.797)">
#          <mask fill="currentColor" id="ftr__d">
#           <use xlink:href="#ftr__c">
#           </use>
#          </mask>
#          <path d="M.05 5.664h5.564V.222H.05z" fill="currentColor" mask="url(#ftr__d)">
#          </path>
#         </g>
#         <g transform="translate(55.433 .97)">
#          <mask fill="currentColor" id="ftr__f">
#           <use xlink:href="#ftr__e">
#           </use>
#          </mask>
#          <path d="M.11 9.444h6.804V.222H.111z" fill="currentColor" mask="url(#ftr__f)">
#          </path>
#         </g>
#         <g transform="translate(33.008 .97)">
#          <mask fill="currentColor" id="ftr__h">
#           <use xlink:href="#ftr__g">
#           </use>
#          </mask>
#          <path d="M.191 9.655h11.611V.04H.192z" fill="currentColor" mask="url(#ftr__h)">
#          </path>
#         </g>
#         <g transform="translate(62.992 .97)">
#          <mask fill="currentColor" id="ftr__j">
#           <use xlink:href="#ftr__i">
#           </use>
#          </mask>
#          <path d="M.141 9.867h7.831V.04H.142z" fill="currentColor" mask="url(#ftr__j)">
#          </path>
#         </g>
#         <g transform="translate(72.063 .97)">
#          <mask fill="currentColor" id="ftr__l">
#           <use xlink:href="#ftr__k">
#           </use>
#          </mask>
#          <path d="M.171 9.655h7.076V.04H.17z" fill="currentColor" mask="url(#ftr__l)">
#          </path>
#         </g>
#         <g transform="translate(46.11 .718)">
#          <mask fill="currentColor" id="ftr__n">
#           <use xlink:href="#ftr__m">
#           </use>
#          </mask>
#          <path d="M.181 10.059h8.225V.232H.18z" fill="currentColor" mask="url(#ftr__n)">
#          </path>
#         </g>
#         <g transform="translate(23.685 .718)">
#          <mask fill="currentColor" id="ftr__p">
#           <use xlink:href="#ftr__o">
#           </use>
#          </mask>
#          <path d="M.05 10.059h8.255V.232H.05z" fill="currentColor" mask="url(#ftr__p)">
#          </path>
#         </g>
#         <g transform="translate(0 .718)">
#          <mask fill="currentColor" id="ftr__r">
#           <use xlink:href="#ftr__q">
#           </use>
#          </mask>
#          <path d="M.03 10.15h7.68V.231H.03z" fill="currentColor" mask="url(#ftr__r)">
#          </path>
#         </g>
#         <g transform="translate(10.33 .718)">
#          <mask fill="currentColor" id="ftr__t">
#           <use xlink:href="#ftr__s">
#           </use>
#          </mask>
#          <path d="M.07 9.907h8.255V.232H.071z" fill="currentColor" mask="url(#ftr__t)">
#          </path>
#         </g>
#         <g transform="translate(84.157 .97)">
#          <mask fill="currentColor" id="ftr__v">
#           <use xlink:href="#ftr__u">
#           </use>
#          </mask>
#          <path d="M.11 9.867h7.046V.04H.11z" fill="currentColor" mask="url(#ftr__v)">
#          </path>
#         </g>
#         <g transform="translate(92.472 .718)">
#          <mask fill="currentColor" id="ftr__x">
#           <use xlink:href="#ftr__w">
#           </use>
#          </mask>
#          <path d="M.08 10.21h9.041V.232H.081z" fill="currentColor" mask="url(#ftr__x)">
#          </path>
#         </g>
#         <g transform="translate(103.811 .718)">
#          <mask fill="currentColor" id="ftr__z">
#           <use xlink:href="#ftr__y">
#           </use>
#          </mask>
#          <path d="M.02 9.907H13.93V.232H.02z" fill="currentColor" mask="url(#ftr__z)">
#          </path>
#         </g>
#         <g transform="translate(120.189 .718)">
#          <mask fill="currentColor" id="ftr__B">
#           <use xlink:href="#ftr__A">
#           </use>
#          </mask>
#          <path d="M.242 13.747H9.01V.232H.242z" fill="currentColor" mask="url(#ftr__B)">
#          </path>
#         </g>
#         <g transform="translate(130.772 .718)">
#          <mask fill="currentColor" id="ftr__D">
#           <use xlink:href="#ftr__C">
#           </use>
#          </mask>
#          <path d="M.06 10.15h7.68V.231H.06z" fill="currentColor" mask="url(#ftr__D)">
#          </path>
#         </g>
#         <g transform="translate(141.102 .718)">
#          <mask fill="currentColor" id="ftr__F">
#           <use xlink:href="#ftr__E">
#           </use>
#          </mask>
#          <path d="M.131 9.907h8.224V.232H.131z" fill="currentColor" mask="url(#ftr__F)">
#          </path>
#         </g>
#         <g transform="translate(150.677 1.222)">
#          <mask fill="currentColor" id="ftr__H">
#           <use xlink:href="#ftr__G">
#           </use>
#          </mask>
#          <path d="M.02 13.455h9.071V0H.021z" fill="currentColor" mask="url(#ftr__H)">
#          </path>
#         </g>
#        </g>
#       </svg>
#      </div>
#      <p class="imdb-footer__copyright _1qNTRY72M5RnFTeiT5Ho-6">
#       © 1990-
#       <!-- -->
#       2020
#       <!-- -->
#       by IMDb.com, Inc.
#      </p>
#     </div>
#    </footer>
#    <svg style="width:0;height:0;overflow:hidden;display:block" version="1.1" xmlns="http://www.w3.org/2000/svg">
#     <defs>
#      <lineargradient id="ipc-svg-gradient-tv-logo-t" x1="31.973%" x2="153.413%" y1="53.409%" y2="-16.853%">
#       <stop offset="21.89%" stop-color="#D01F49">
#       </stop>
#       <stop offset="83.44%" stop-color="#E8138B">
#       </stop>
#      </lineargradient>
#      <lineargradient id="ipc-svg-gradient-tv-logo-v" x1="-38.521%" x2="104.155%" y1="84.997%" y2="14.735%">
#       <stop offset="21.89%" stop-color="#D01F49">
#       </stop>
#       <stop offset="83.44%" stop-color="#E8138B">
#       </stop>
#      </lineargradient>
#     </defs>
#    </svg>
#    <script>
#     if (typeof uet == 'function') {
#                 uet("be", "responsiveFooter", {wb: 1});
#             }
#    </script>
#    <script>
#     if (typeof uex == 'function') {
#                 uex("ld", "responsiveFooter", {wb: 1});
#             }
#    </script>
#    <svg style="width:0;height:0;overflow:hidden;display:block" version="1.1" xmlns="http://www.w3.org/2000/svg">
#     <defs>
#      <lineargradient id="ipc-svg-gradient-tv-logo-t" x1="31.973%" x2="153.413%" y1="53.409%" y2="-16.853%">
#       <stop offset="21.89%" stop-color="#D01F49">
#       </stop>
#       <stop offset="83.44%" stop-color="#E8138B">
#       </stop>
#      </lineargradient>
#      <lineargradient id="ipc-svg-gradient-tv-logo-v" x1="-38.521%" x2="104.155%" y1="84.997%" y2="14.735%">
#       <stop offset="21.89%" stop-color="#D01F49">
#       </stop>
#       <stop offset="83.44%" stop-color="#E8138B">
#       </stop>
#      </lineargradient>
#     </defs>
#    </svg>
#   </div>
#   <script async="" type="text/javascript">
#    !window.__BoomerFullPageData__ && (window.__BoomerFullPageData__ = {}); window.__BoomerFullPageData__["IMDbHomepageSiteReactViews"] = "...";
#   </script>
#   <script defer="" src="https://m.media-amazon.com/images/I/81OZopU5GHL.js">
#   </script>
#   <script defer="" src="https://m.media-amazon.com/images/I/61SeeyqsNHL.js">
#   </script>
#   <script defer="" src="https://m.media-amazon.com/images/I/71rDQFcVeSL.js">
#   </script>
#   <script defer="" src="https://m.media-amazon.com/images/I/61IuCnjrlZL.js">
#   </script>
#   <script defer="" src="https://m.media-amazon.com/images/I/6163Hta536L.js">
#   </script>
#   <script defer="" src="https://m.media-amazon.com/images/I/41EGorqaRtL.js">
#   </script>
#   <script defer="" src="https://m.media-amazon.com/images/I/81blQr4LFDL.js">
#   </script>
#   <script defer="" src="https://m.media-amazon.com/images/I/61QEx0-qAoL.js">
#   </script>
#   <script defer="" src="https://m.media-amazon.com/images/I/61u0PMi4qkL.js">
#   </script>
#   <script defer="" src="https://m.media-amazon.com/images/I/31827uXCh4L.js">
#   </script>
#   <script defer="" src="https://m.media-amazon.com/images/I/51V3qAz9DRL.js">
#   </script>
#   <script defer="" src="https://m.media-amazon.com/images/I/41JWfb4tn9L.js">
#   </script>
#   <script defer="" src="https://m.media-amazon.com/images/I/31CVeMZywWL.js">
#   </script>
#   <script defer="" src="https://m.media-amazon.com/images/I/41Dm6cYzV6L.js">
#   </script>
#   <script defer="" src="https://m.media-amazon.com/images/I/5129P-6KQBL.js">
#   </script>
#   <script defer="" src="https://m.media-amazon.com/images/I/41gjX8bUr9L.js">
#   </script>
#   <script defer="" src="https://m.media-amazon.com/images/I/31hCFTHe4HL.js">
#   </script>
#   <script defer="" src="https://m.media-amazon.com/images/I/31opZUbUVAL.js">
#   </script>
#   <script defer="" src="https://m.media-amazon.com/images/I/21SCiQebD6L.js">
#   </script>
#   <script defer="" src="https://m.media-amazon.com/images/I/21klWUDt+mL.js">
#   </script>
#   <script defer="" src="https://m.media-amazon.com/images/I/21VvgXRZHTL.js">
#   </script>
#   <script defer="" src="https://m.media-amazon.com/images/I/21+8Q2WVhGL.js">
#   </script>
#   <script defer="" src="https://m.media-amazon.com/images/I/31hQNx7wlcL.js">
#   </script>
#   <script defer="" src="https://m.media-amazon.com/images/I/31Dhu5PPSQL.js">
#   </script>
#   <script defer="" src="https://m.media-amazon.com/images/I/41GjDlxNgpL.js">
#   </script>
#   <script defer="" src="https://m.media-amazon.com/images/I/21OTLRDTmBL.js">
#   </script>
#   <script defer="" src="https://m.media-amazon.com/images/I/31K-W7Ds3yL.js">
#   </script>
#   <script defer="" src="https://m.media-amazon.com/images/I/41JVCESGUVL.js">
#   </script>
#   <script defer="" src="https://m.media-amazon.com/images/I/314ajh92krL.js">
#   </script>
#   <script defer="" src="https://m.media-amazon.com/images/I/21yhdBRM2zL.js">
#   </script>
#   <script defer="" src="https://m.media-amazon.com/images/I/11Ki+Pl34wL.js">
#   </script>
#   <script defer="" src="https://m.media-amazon.com/images/I/01xfXgM7bsL.js">
#   </script>
#   <script defer="" src="https://m.media-amazon.com/images/I/61Ka2ezTX9L.js">
#   </script>
#   <script defer="" src="https://m.media-amazon.com/images/I/012qVvaa4SL.js">
#   </script>
#   <script defer="" src="https://m.media-amazon.com/images/I/01zuBCOPcIL.js">
#   </script>
#   <script defer="" src="https://m.media-amazon.com/images/I/019vMGkrlkL.js">
#   </script>
#   <script defer="" src="https://m.media-amazon.com/images/I/21th+zfZMcL.js">
#   </script>
#   <script defer="" src="https://m.media-amazon.com/images/I/11igy6+WUkL.js">
#   </script>
#   <script defer="" src="https://m.media-amazon.com/images/I/11UNuUz7BzL.js">
#   </script>
#   <script defer="" src="https://m.media-amazon.com/images/I/11yQ0Di98jL.js">
#   </script>
#   <script defer="" src="https://m.media-amazon.com/images/I/21QhnrxvhtL.js">
#   </script>
#   <script defer="" src="https://m.media-amazon.com/images/I/11S4fR+qCGL.js">
#   </script>
#   <script defer="" src="https://m.media-amazon.com/images/I/01EjywnajPL.js">
#   </script>
#   <script defer="" src="https://m.media-amazon.com/images/I/01eEXY1YetL.js">
#   </script>
#   <script defer="" src="https://m.media-amazon.com/images/I/21n5fdlWBhL.js">
#   </script>
#   <script defer="" src="https://m.media-amazon.com/images/I/21a9eB+eAFL.js">
#   </script>
#   <script defer="" src="https://m.media-amazon.com/images/I/51x9DfOUwML.js">
#   </script>
#  </body>
# </html>

# %% [markdown]
# ### Find links
#
# In many cases, it is useful to collect the links contained in a webpage (for example, you might want to scrape them too or webcrawl). Here is how you can do this.

# %%
# Find all links
links = [link.get('href') for link in imdb_soup.find_all('a')]

# Add homepage and keep the unique links
fixed_links = set([''.join([imdb_url, link]) for link in links if link])

fixed_links
# Out:
# {'https://www.imdb.com/?ref_=nv_home',
#  'https://www.imdb.com/awards-central/?ref_=nv_ev_awrd',
#  'https://www.imdb.com/chart/boxoffice/?ref_=nv_ch_cht',
#  'https://www.imdb.com/chart/moviemeter/?ref_=nv_mv_mpm',
#  'https://www.imdb.com/chart/top/?ref_=nv_mv_250',
#  'https://www.imdb.com/chart/toptv/?ref_=nv_tvv_250',
#  'https://www.imdb.com/chart/tvmeter/?ref_=nv_tvv_mptv',
#  'https://www.imdb.com/comic-con/?ref_=nv_ev_comic',
#  'https://www.imdb.com/conditions?ref_=ft_cou',
#  'https://www.imdb.com/emmys/?ref_=nv_ev_rte',
#  'https://www.imdb.com/feature/bornondate/?ref_=nv_cel_brn',
#  'https://www.imdb.com/festival-central/?ref_=nv_ev_fc',
#  'https://www.imdb.com/golden-globes/?ref_=nv_ev_gg',
#  'https://www.imdb.com/imdbpicks/?ref_=nv_pi',
#  'https://www.imdb.com/imdbpicks/latest-posters/rg1624939264/mediaviewer/rm1408607489?pf_rd_r=HD4GAX0GD15GA4ZZR4JW&pf_rd_p=7d5903c4-cdfd-4c8d-89e3-9203220f670b&pf_rd_m=A2FGELUUNOQJNL&pf_rd_t=15061&pf_rd_i=home&pf_rd_s=featured-today-2&ref_=hm_edcft_ft_posters_2',
#  'https://www.imdb.com/imdbpicks/photos-we-love/rg1641716480/mediaviewer/rm2798691585?pf_rd_r=HD4GAX0GD15GA4ZZR4JW&pf_rd_p=598499fb-1b3f-4bbb-a513-7fba497e76cb&pf_rd_m=A2FGELUUNOQJNL&pf_rd_t=15061&pf_rd_i=home&pf_rd_s=featured-today-3&ref_=hm_edcft_ph_pwl_3',
#  'https://www.imdb.com/india/toprated/?ref_=nv_mv_in',
#  'https://www.imdb.com/india/tv?ref_=nv_tv_in',
#  'https://www.imdb.com/list/ls025720609/videoplayer/vi1147518489?ref_=hp_hp_e_2',
#  'https://www.imdb.com/list/ls025720609/videoplayer/vi832225561?ref_=hp_hp_e_4',
#  'https://www.imdb.com/list/ls053181649/videoplayer/vi1302249753?ref_=hp_hp_e_11',
#  'https://www.imdb.com/list/ls053181649/videoplayer/vi1921171737?ref_=hp_hp_e_3',
#  'https://www.imdb.com/list/ls053181649/videoplayer/vi3548627225?ref_=hm_hp_i_1',
#  'https://www.imdb.com/list/ls053181649/videoplayer/vi3548627225?ref_=hp_hp_e_1',
#  'https://www.imdb.com/list/ls053181649/videoplayer/vi4119183641?ref_=hp_hp_e_5',
#  'https://www.imdb.com/list/watchlist?ref_=nv_usr_wl_all_0',
#  'https://www.imdb.com/news/celebrity/?ref_=nv_cel_nw',
#  'https://www.imdb.com/news/movie/?ref_=nv_nw_mv',
#  'https://www.imdb.com/news/tv/?ref_=nv_nw_tv',
#  'https://www.imdb.com/nycc/?ref_=nv_ev_nycc',
#  'https://www.imdb.com/originals/?ref_=nv_sf_ori',
#  'https://www.imdb.com/oscars/?ref_=nv_ev_acd',
#  'https://www.imdb.com/podcasts/?ref_=nv_pod',
#  'https://www.imdb.com/poll/?ref_=nv_cm_pl',
#  'https://www.imdb.com/privacy?ref_=ft_pvc',
#  'https://www.imdb.com/registration/signin?ref=nv_generic_lgin',
#  'https://www.imdb.com/registration/signin?ref_=hm_wls_signin',
#  'https://www.imdb.com/scary-good/hollywood-heartthrobs/rg1738382080/mediaviewer/rm902866177?pf_rd_r=HD4GAX0GD15GA4ZZR4JW&pf_rd_p=0e3c8e11-21ff-4375-a063-b3889cc37ee8&pf_rd_m=A2FGELUUNOQJNL&pf_rd_t=15061&pf_rd_i=home&pf_rd_s=featured-today-1&ref_=hm_edcft_scg_hht_1',
#  'https://www.imdb.com/starmeterawards/?ref_=nv_ev_sma',
#  'https://www.imdb.com/sundance/?ref_=nv_ev_sun',
#  'https://www.imdb.com/title/tt8356942?ref_=hm_hp_cap_pri_1',
#  'https://www.imdb.com/toronto/?ref_=nv_ev_tor',
#  'https://www.imdb.com/trailers/?ref_=hm_hp_sm',
#  'https://www.imdb.com/trailers/?ref_=nv_mv_tr',
#  'https://www.imdb.com/tv/?ref_=ft_fdv',
#  'https://www.imdb.com/tv/?ref_=nv_tp_fdv',
#  'https://www.imdb.com/tv/?ref_=nv_vid_tv',
#  'https://www.imdb.com/what-to-watch/?ref_=nv_watch',
#  'https://www.imdb.com/what-to-watch/from-your-watchlist/?ref_=hm_wls_sm',
#  'https://www.imdb.com/what-to-watch/popular/?ref_=hm_watch_pop',
#  'https://www.imdb.com/what-to-watch/watch-guides/?ref_=hm_watch_wchgd',
#  'https://www.imdb.com/what-to-watch?ref_=hm_watch_btn',
#  'https://www.imdb.com/whitelist-offsite?url=https%3A%2F%2Ffacebook.com%2Fimdb&page-action=fol_fb&ref=ft_fol_fb',
#  'https://www.imdb.com/whitelist-offsite?url=https%3A%2F%2Finstagram.com%2Fimdb&page-action=fol_inst&ref=ft_fol_inst',
#  'https://www.imdb.com/whitelist-offsite?url=https%3A%2F%2Ftqp-4.tlnk.io%2Fserve%3Faction%3Dclick%26campaign_id_android%3D427112%26campaign_id_ios%3D427111%26destination_id_android%3D464200%26destination_id_ios%3D464199%26my_campaign%3Dmdot%2520sitewide%2520footer%2520%26my_site%3Dm.imdb.com%26publisher_id%3D350552%26site_id_android%3D133429%26site_id_ios%3D133428&page-action=ft-gettheapp&ref=ft_apps',
#  'https://www.imdb.com/whitelist-offsite?url=https%3A%2F%2Ftwitch.tv%2FIMDb&page-action=fol_twch&ref=ft_fol_twch',
#  'https://www.imdb.com/whitelist-offsite?url=https%3A%2F%2Ftwitter.com%2Fimdb&page-action=fol_tw&ref=ft_fol_tw',
#  'https://www.imdb.com/whitelist-offsite?url=https%3A%2F%2Fwww.amazon.com%2Fb%2F%3F%26node%3D5160028011%26ref_%3Dft_iba&page-action=ft-iba&ref=ft_iba',
#  'https://www.imdb.com/whitelist-offsite?url=https%3A%2F%2Fyoutube.com%2Fimdb%2F&page-action=fol_yt&ref=ft_fol_yt',
#  'https://www.imdb.comhttps://advertising.amazon.com/resources/ad-specs/imdb/?ref_=a20m_us_spcs_imdb',
#  'https://www.imdb.comhttps://contribute.imdb.com/czone?ref_=nv_cm_cz',
#  'https://www.imdb.comhttps://developer.imdb.com/?ref=ft_ds',
#  'https://www.imdb.comhttps://help.imdb.com/article/imdb/general-information/imdb-site-index/GNCX7BHNSPBTFALQ?ref_=ft_si#so',
#  'https://www.imdb.comhttps://help.imdb.com/imdb?ref_=cons_nb_hlp',
#  'https://www.imdb.comhttps://help.imdb.com/imdb?ref_=ft_hlp',
#  'https://www.imdb.comhttps://m.imdb.com/chart/starmeter/?ref_=nv_cel_brn',
#  'https://www.imdb.comhttps://m.imdb.com/coming-soon/?ref_=nv_mv_cs',
#  'https://www.imdb.comhttps://m.imdb.com/feature/bestpicture/?ref_=nv_ch_osc',
#  'https://www.imdb.comhttps://m.imdb.com/showtimes/movie/?ref_=nv_mv_sh',
#  'https://www.imdb.comhttps://m.imdb.com/whats-on-tv/?ref_=nv_tv_ontv',
#  'https://www.imdb.comhttps://pro.imdb.com/login/ap?u=/login/lwa&imdbPageAction=signUp&rf=cons_nb_hm&ref_=cons_nb_hm',
#  'https://www.imdb.comhttps://pro.imdb.com?ref_=cons_nb_hm&rf=cons_nb_hm',
#  'https://www.imdb.comhttps://pro.imdb.com?ref_=ft_pro&rf=cons_tf_pro',
#  'https://www.imdb.comhttps://www.amazon.jobs/en/teams/imdb?ref_=ft_jb',
#  'https://www.imdb.comhttps://www.boxofficemojo.com',
#  'https://www.imdb.comhttps://www.imdb.com/calendar/?ref_=nv_mv_cal',
#  'https://www.imdb.comhttps://www.imdb.com/coming-soon/?ref_=nv_mv_cs',
#  'https://www.imdb.comhttps://www.imdb.com/event/all/?ref_=nv_ev_all',
#  'https://www.imdb.comhttps://www.imdb.com/feature/genre/?ref_=nv_ch_gr',
#  'https://www.imdb.comhttps://www.imdb.com/feature/genre/?ref_=nv_tv_gr',
#  'https://www.imdb.comhttps://www.imdb.com/list/ls016522954/?ref_=nv_tvv_dvd',
#  'https://www.imdb.comhttps://www.imdb.com/movies-in-theaters/?ref_=nv_mv_inth',
#  'https://www.imdb.comhttps://www.imdb.com/pressroom/?ref_=ft_pr',
#  'https://www.imdb.comhttps://www.imdb.com/search/',
#  'https://www.imdb.comhttps://www.imdb.com/search/name/?gender=male%2Cfemale&ref_=nv_cel_m',
#  'https://www.imdb.comhttps://www.imdb.com/search/title/?count=100&groups=oscar_best_picture_winners&sort=year%2Cdesc&ref_=nv_ch_osc',
#  'https://www.imdb.comhttps://www.imdb.com/showtimes/?ref_=nv_mv_sh',
#  'https://www.imdb.comhttps://www.imdb.com/whats-on-tv/?ref_=nv_tv_ontv'}

# %% [markdown]
# # Let's scrape IMDB's top 250 movies

# %%
url = 'http://www.imdb.com/chart/top'
response = requests.get(url)

imdb_soup = BeautifulSoup(response.text, 'lxml') #we're going to read the information we got with beautiful soup
# and it will read lxml and html code for you. learn more here: https://lxml.de/

# %% [markdown]
# ### Let's explore the information related to:
# * title of movie
# * year of the movie
# * ranking
# * links (this will be useful if we want to scrape additional information about that movie later on)
# * the crew (director and star cast)
# * IMDb ratings
#
# -> Go to your inspector page and find the relevant tags to these things
#
# What's easy to find:
# 1. title =  titleColumn (with tag td)
# 2. Imdb rating = ratingColumn.idbmRating  (with tag td)
#
# What about the other stuff?
#
# We can find what's within tags using `find`

# %%
imdb_soup.find('td', {'class': 'titleColumn'})
# Out:
# <td class="titleColumn">
#       1.
#       <a href="/title/tt0111161/" title="Frank Darabont (dir.), Tim Robbins, Morgan Freeman">The Shawshank Redemption</a>
# <span class="secondaryInfo">(1994)</span>
# </td>

# %%
imdb_soup.find('td', {'class': 'ratingColumn'})
# Out:
# <td class="ratingColumn imdbRating">
# <strong title="9.2 based on 2,291,236 user ratings">9.2</strong>
# </td>

# %% [markdown]
# We will use the `.find_all()` method to search the HTML tree for particular tags and get a `list` with all the relevant objects.

# %%
imdb_title = imdb_soup.find_all('td', {'class': 'titleColumn'})

# %%
# you can turn this into a dataframe, but it's quite messy 
# and we'd need to clean it up and it's the first bit of what we want
imdb_table= pd.DataFrame(imdb_title).drop([2,4],1)
imdb_table[0]= imdb_table[0].str.strip('\n .')
imdb_table[1]= imdb_table[1].str.join(', ') #turn lists into values
imdb_table[3]= imdb_table[3].str.join(', ').str.strip('( )')
imdb_table.columns='ranking','movie','year'
imdb_table

#tbh, I often scrape like this and then join pieces of the dataframes together. Doesn't really matter how you do it.
# Out:
#     ranking                     movie  year
# 0         1  The Shawshank Redemption  1994
# 1         2             The Godfather  1972
# 2         3    The Godfather: Part II  1974
# 3         4           The Dark Knight  2008
# 4         5              12 Angry Men  1957
# ..      ...                       ...   ...
# 245     246            The Terminator  1984
# 246     247                Tangerines  2013
# 247     248                   Aladdin  1992
# 248     249       Fanny and Alexander  1982
# 249     250         Three Colors: Red  1994
#
# [250 rows x 3 columns]

# %% [markdown]
# ## Another way to add even more information

# %% [markdown]
# We could just analyze what's the selectors that we need and then create a list out of it
# We'll use the `select` function to do this

# %%
# you can do this by analyzing the website, or you can widdle down the info with our
# find option
imdb_soup.find('td', {'class': 'titleColumn'})
# Out:
# <td class="titleColumn">
#       1.
#       <a href="/title/tt0111161/" title="Frank Darabont (dir.), Tim Robbins, Morgan Freeman">The Shawshank Redemption</a>
# <span class="secondaryInfo">(1994)</span>
# </td>

# %%
#given the above
# href is always a link in html so, that's a hint to store that information
#notice how it is under the class tag "a"
#title has my crew info, also under the tag "a"
# year information is in the class "secondaryInfo"

movies = imdb_soup.select('td.titleColumn') #I'm going to select the title information
year = imdb_soup.select('span.secondaryInfo')#I'm going to select the year information

# a bit more tricky is getting the attribute href and title from the node "a"
#we'll use list comprehension to create a list of values that looks into the node td.titleColumn a and get 
# attributes related to our keywords

links = [a.attrs.get('href') for a in imdb_soup.select('td.titleColumn a')] #get the links
crew = [a.attrs.get('title') for a in imdb_soup.select('td.titleColumn a')] #get the crew

# %%
imdb_soup.find('td', {'class': 'posterColumn'})
# Out:
# <td class="posterColumn">
# <span data-value="1" name="rk"></span>
# <span data-value="9.222790917333004" name="ir"></span>
# <span data-value="7.791552E11" name="us"></span>
# <span data-value="2291236" name="nv"></span>
# <span data-value="-1.777209082666996" name="ur"></span>
# <a href="/title/tt0111161/"> <img alt="The Shawshank Redemption" height="67" src="https://m.media-amazon.com/images/M/MV5BMDFkYTc0MGEtZmNhMC00ZDIzLWFmNTEtODM1ZmRlYWMwMWFmXkEyXkFqcGdeQXVyMTMxODk2OTU@._V1_UY67_CR0,0,45,67_AL_.jpg" width="45"/>
# </a> </td>

# %%
# And based on the above, we can collect the rating
ratings = [b.attrs.get('data-value') for b in imdb_soup.select('td.posterColumn span[name=ir]')]

# %% [markdown]
# ### So, we got a list of stuff, how do we put it together?

# %%
movies[0]
# Out:
# <td class="titleColumn">
#       1.
#       <a href="/title/tt0111161/" title="Frank Darabont (dir.), Tim Robbins, Morgan Freeman">The Shawshank Redemption</a>
# <span class="secondaryInfo">(1994)</span>
# </td>

# %%
# we're going to for loop and append everything into one giant nested list.
# as we move along, we'll clean the data

#first, we're going to get the information contained in movies. Remember that this is a dictionary. 
#so I'm going to call the index from the list we created of movies and get the text
#here is an example of the last item in the dicitonary

#let's name this
movie_string = movies[0].get_text()
movies[0].get_text()
# Out:
# '\n      1.\n      The Shawshank Redemption\n(1994)\n'

# %% [markdown]
# I'm going to clean it up
#
# First, I'll join the items in the string together with ('',join())
#
# Then, I'm going to split this information into a list by using a space as the splitter with `.split()`
#
# Then, I'll delete that pesky '.' using `.replace`

# %%
# This looks a lot nicer
movie = (' '.join(movie_string.split()).replace('.', ''))
(' '.join(movie_string.split()).replace('.', ''))
# Out:
# '1 The Shawshank Redemption (1994)'

# %%
# I'm going to remove the last 6 digits of the movie name to get rid of the year
movie_title = movie[len(str(0))+1:-7]
movie[len(str(0))+1:-7]
# Out:
# 'The Shawshank Redemption'

# %%
#I'll do the same thing to the years variable
year_string = year[0].get_text()
years = (' '.join(year_string.split()).replace('(', '').replace(')', ''))
years
# Out:
# '1994'

# %%
# I'll use the existing place indexes in the table to create the ranking 
ranking = movie[:len(str(0))-(len(movie))]
movie[:len(str(0))-(len(movie))]
# Out:
# '1'

# %%
# Then I'll build out a dictionary
data = {"movie_title": movie_title,
            "year": years,
            "ranking": ranking,
            "star_cast": crew[0],
            "rating": ratings[0],
            "link": links[0]}
data
# Out:
# {'movie_title': 'The Shawshank Redemption',
#  'year': '1994',
#  'ranking': '1',
#  'star_cast': 'Frank Darabont (dir.), Tim Robbins, Morgan Freeman',
#  'rating': '9.222790917333004',
#  'link': '/title/tt0111161/'}

# %%
len(movies)
# Out:
# 250

# %%
# I'll turn this into a for loop, append each item 
imdb =[]
for index in range(len(movies)):
    # Seperate movie into: 'place', 'title', 'year'
    movie_string = movies[index].get_text()
    movie = (' '.join(movie_string.split()).replace('.', ''))
    movie_title = movie[len(str(index))+1:-7]
    year_string = year[index].get_text()
    years = (' '.join(year_string.split()).replace('(', '').replace(')', ''))
    rankings = movie[:len(str(index))-(len(movie))]
    data = {"movie_title": movie_title,
            "year": years,
            "ranking": rankings,
            "star_cast": crew[index],
            "rating": ratings[index],
            "link": links[index]}
    imdb.append(data)
imdb
# Out:
# [{'movie_title': 'The Shawshank Redemption',
#   'year': '1994',
#   'ranking': '1',
#   'star_cast': 'Frank Darabont (dir.), Tim Robbins, Morgan Freeman',
#   'rating': '9.222790917333004',
#   'link': '/title/tt0111161/'},
#  {'movie_title': 'The Godfather',
#   'year': '1972',
#   'ranking': '2',
#   'star_cast': 'Francis Ford Coppola (dir.), Marlon Brando, Al Pacino',
#   'rating': '9.14877186687596',
#   'link': '/title/tt0068646/'},
#  {'movie_title': 'The Godfather: Part II',
#   'year': '1974',
#   'ranking': '3',
#   'star_cast': 'Francis Ford Coppola (dir.), Al Pacino, Robert De Niro',
#   'rating': '8.981171792324258',
#   'link': '/title/tt0071562/'},
#  {'movie_title': 'The Dark Knight',
#   'year': '2008',
#   'ranking': '4',
#   'star_cast': 'Christopher Nolan (dir.), Christian Bale, Heath Ledger',
#   'rating': '8.973475292618291',
#   'link': '/title/tt0468569/'},
#  {'movie_title': '12 Angry Men',
#   'year': '1957',
#   'ranking': '5',
#   'star_cast': 'Sidney Lumet (dir.), Henry Fonda, Lee J. Cobb',
#   'rating': '8.930520290799217',
#   'link': '/title/tt0050083/'},
#  {'movie_title': "Schindler's List",
#   'year': '1993',
#   'ranking': '6',
#   'star_cast': 'Steven Spielberg (dir.), Liam Neeson, Ralph Fiennes',
#   'rating': '8.907357112354246',
#   'link': '/title/tt0108052/'},
#  {'movie_title': 'The Lord of the Rings: The Return of the King',
#   'year': '2003',
#   'ranking': '7',
#   'star_cast': 'Peter Jackson (dir.), Elijah Wood, Viggo Mortensen',
#   'rating': '8.883637003260363',
#   'link': '/title/tt0167260/'},
#  {'movie_title': 'Pulp Fiction',
#   'year': '1994',
#   'ranking': '8',
#   'star_cast': 'Quentin Tarantino (dir.), John Travolta, Uma Thurman',
#   'rating': '8.845215196959192',
#   'link': '/title/tt0110912/'},
#  {'movie_title': 'The Good, the Bad and the Ugly',
#   'year': '1966',
#   'ranking': '9',
#   'star_cast': 'Sergio Leone (dir.), Clint Eastwood, Eli Wallach',
#   'rating': '8.796354689376406',
#   'link': '/title/tt0060196/'},
#  {'movie_title': ' The Lord of the Rings: The Fellowship of the Ring',
#   'year': '2001',
#   'ranking': '1',
#   'star_cast': 'Peter Jackson (dir.), Elijah Wood, Ian McKellen',
#   'rating': '8.77519571755578',
#   'link': '/title/tt0120737/'},
#  {'movie_title': 'Fight Club',
#   'year': '1999',
#   'ranking': '11',
#   'star_cast': 'David Fincher (dir.), Brad Pitt, Edward Norton',
#   'rating': '8.766633120798764',
#   'link': '/title/tt0137523/'},
#  {'movie_title': 'Forrest Gump',
#   'year': '1994',
#   'ranking': '12',
#   'star_cast': 'Robert Zemeckis (dir.), Tom Hanks, Robin Wright',
#   'rating': '8.753083081560675',
#   'link': '/title/tt0109830/'},
#  {'movie_title': 'Inception',
#   'year': '2010',
#   'ranking': '13',
#   'star_cast': 'Christopher Nolan (dir.), Leonardo DiCaprio, Joseph Gordon-Levitt',
#   'rating': '8.721053341726993',
#   'link': '/title/tt1375666/'},
#  {'movie_title': 'The Lord of the Rings: The Two Towers',
#   'year': '2002',
#   'ranking': '14',
#   'star_cast': 'Peter Jackson (dir.), Elijah Wood, Ian McKellen',
#   'rating': '8.698695031772383',
#   'link': '/title/tt0167261/'},
#  {'movie_title': 'Star Wars: Episode V - The Empire Strikes Back',
#   'year': '1980',
#   'ranking': '15',
#   'star_cast': 'Irvin Kershner (dir.), Mark Hamill, Harrison Ford',
#   'rating': '8.698512844388532',
#   'link': '/title/tt0080684/'},
#  {'movie_title': 'The Matrix',
#   'year': '1999',
#   'ranking': '16',
#   'star_cast': 'Lana Wachowski (dir.), Keanu Reeves, Laurence Fishburne',
#   'rating': '8.648556972346732',
#   'link': '/title/tt0133093/'},
#  {'movie_title': 'Goodfellas',
#   'year': '1990',
#   'ranking': '17',
#   'star_cast': 'Martin Scorsese (dir.), Robert De Niro, Ray Liotta',
#   'rating': '8.643259411535926',
#   'link': '/title/tt0099685/'},
#  {'movie_title': "One Flew Over the Cuckoo's Nest",
#   'year': '1975',
#   'ranking': '18',
#   'star_cast': 'Milos Forman (dir.), Jack Nicholson, Louise Fletcher',
#   'rating': '8.63897233627842',
#   'link': '/title/tt0073486/'},
#  {'movie_title': 'Seven Samurai',
#   'year': '1954',
#   'ranking': '19',
#   'star_cast': 'Akira Kurosawa (dir.), Toshirô Mifune, Takashi Shimura',
#   'rating': '8.603972164405514',
#   'link': '/title/tt0047478/'},
#  {'movie_title': 'Se7en',
#   'year': '1995',
#   'ranking': '20',
#   'star_cast': 'David Fincher (dir.), Morgan Freeman, Brad Pitt',
#   'rating': '8.591930523080848',
#   'link': '/title/tt0114369/'},
#  {'movie_title': 'Life Is Beautiful',
#   'year': '1997',
#   'ranking': '21',
#   'star_cast': 'Roberto Benigni (dir.), Roberto Benigni, Nicoletta Braschi',
#   'rating': '8.583003325505812',
#   'link': '/title/tt0118799/'},
#  {'movie_title': 'City of God',
#   'year': '2002',
#   'ranking': '22',
#   'star_cast': 'Fernando Meirelles (dir.), Alexandre Rodrigues, Leandro Firmino',
#   'rating': '8.580196854341843',
#   'link': '/title/tt0317248/'},
#  {'movie_title': 'The Silence of the Lambs',
#   'year': '1991',
#   'ranking': '23',
#   'star_cast': 'Jonathan Demme (dir.), Jodie Foster, Anthony Hopkins',
#   'rating': '8.575462831631665',
#   'link': '/title/tt0102926/'},
#  {'movie_title': "It's a Wonderful Life",
#   'year': '1946',
#   'ranking': '24',
#   'star_cast': 'Frank Capra (dir.), James Stewart, Donna Reed',
#   'rating': '8.571259538268954',
#   'link': '/title/tt0038650/'},
#  {'movie_title': 'Star Wars: Episode IV - A New Hope',
#   'year': '1977',
#   'ranking': '25',
#   'star_cast': 'George Lucas (dir.), Mark Hamill, Harrison Ford',
#   'rating': '8.556118192377948',
#   'link': '/title/tt0076759/'},
#  {'movie_title': 'Saving Private Ryan',
#   'year': '1998',
#   'ranking': '26',
#   'star_cast': 'Steven Spielberg (dir.), Tom Hanks, Matt Damon',
#   'rating': '8.549312066696428',
#   'link': '/title/tt0120815/'},
#  {'movie_title': 'Spirited Away',
#   'year': '2001',
#   'ranking': '27',
#   'star_cast': 'Hayao Miyazaki (dir.), Daveigh Chase, Suzanne Pleshette',
#   'rating': '8.540719007447365',
#   'link': '/title/tt0245429/'},
#  {'movie_title': 'The Green Mile',
#   'year': '1999',
#   'ranking': '28',
#   'star_cast': 'Frank Darabont (dir.), Tom Hanks, Michael Clarke Duncan',
#   'rating': '8.537853424485341',
#   'link': '/title/tt0120689/'},
#  {'movie_title': 'Parasite',
#   'year': '2019',
#   'ranking': '29',
#   'star_cast': 'Bong Joon Ho (dir.), Kang-ho Song, Sun-kyun Lee',
#   'rating': '8.533477476825375',
#   'link': '/title/tt6751668/'},
#  {'movie_title': 'Interstellar',
#   'year': '2014',
#   'ranking': '30',
#   'star_cast': 'Christopher Nolan (dir.), Matthew McConaughey, Anne Hathaway',
#   'rating': '8.531661265393886',
#   'link': '/title/tt0816692/'},
#  {'movie_title': 'Léon: The Professional',
#   'year': '1994',
#   'ranking': '31',
#   'star_cast': 'Luc Besson (dir.), Jean Reno, Gary Oldman',
#   'rating': '8.51095675474166',
#   'link': '/title/tt0110413/'},
#  {'movie_title': 'The Usual Suspects',
#   'year': '1995',
#   'ranking': '32',
#   'star_cast': 'Bryan Singer (dir.), Kevin Spacey, Gabriel Byrne',
#   'rating': '8.499287836439347',
#   'link': '/title/tt0114814/'},
#  {'movie_title': 'Harakiri',
#   'year': '1962',
#   'ranking': '33',
#   'star_cast': 'Masaki Kobayashi (dir.), Tatsuya Nakadai, Akira Ishihama',
#   'rating': '8.49758693180844',
#   'link': '/title/tt0056058/'},
#  {'movie_title': 'The Lion King',
#   'year': '1994',
#   'ranking': '34',
#   'star_cast': 'Roger Allers (dir.), Matthew Broderick, Jeremy Irons',
#   'rating': '8.491861636533093',
#   'link': '/title/tt0110357/'},
#  {'movie_title': 'Back to the Future',
#   'year': '1985',
#   'ranking': '35',
#   'star_cast': 'Robert Zemeckis (dir.), Michael J. Fox, Christopher Lloyd',
#   'rating': '8.486760868361474',
#   'link': '/title/tt0088763/'},
#  {'movie_title': 'The Pianist',
#   'year': '2002',
#   'ranking': '36',
#   'star_cast': 'Roman Polanski (dir.), Adrien Brody, Thomas Kretschmann',
#   'rating': '8.4865936587629',
#   'link': '/title/tt0253474/'},
#  {'movie_title': 'Terminator 2: Judgment Day',
#   'year': '1991',
#   'ranking': '37',
#   'star_cast': 'James Cameron (dir.), Arnold Schwarzenegger, Linda Hamilton',
#   'rating': '8.485899379255573',
#   'link': '/title/tt0103064/'},
#  {'movie_title': 'American History X',
#   'year': '1998',
#   'ranking': '38',
#   'star_cast': 'Tony Kaye (dir.), Edward Norton, Edward Furlong',
#   'rating': '8.483636555887207',
#   'link': '/title/tt0120586/'},
#  {'movie_title': 'Modern Times',
#   'year': '1936',
#   'ranking': '39',
#   'star_cast': 'Charles Chaplin (dir.), Charles Chaplin, Paulette Goddard',
#   'rating': '8.482769510439699',
#   'link': '/title/tt0027977/'},
#  {'movie_title': 'Hamilton',
#   'year': '2020',
#   'ranking': '40',
#   'star_cast': 'Thomas Kail (dir.), Lin-Manuel Miranda, Phillipa Soo',
#   'rating': '8.47742586464334',
#   'link': '/title/tt8503618/'},
#  {'movie_title': 'Psycho',
#   'year': '1960',
#   'ranking': '41',
#   'star_cast': 'Alfred Hitchcock (dir.), Anthony Perkins, Janet Leigh',
#   'rating': '8.47714941339857',
#   'link': '/title/tt0054215/'},
#  {'movie_title': 'Gladiator',
#   'year': '2000',
#   'ranking': '42',
#   'star_cast': 'Ridley Scott (dir.), Russell Crowe, Joaquin Phoenix',
#   'rating': '8.476393402729428',
#   'link': '/title/tt0172495/'},
#  {'movie_title': 'City Lights',
#   'year': '1931',
#   'ranking': '43',
#   'star_cast': 'Charles Chaplin (dir.), Charles Chaplin, Virginia Cherrill',
#   'rating': '8.472363754719623',
#   'link': '/title/tt0021749/'},
#  {'movie_title': 'The Departed',
#   'year': '2006',
#   'ranking': '44',
#   'star_cast': 'Martin Scorsese (dir.), Leonardo DiCaprio, Matt Damon',
#   'rating': '8.471685411419854',
#   'link': '/title/tt0407887/'},
#  {'movie_title': 'The Intouchables',
#   'year': '2011',
#   'ranking': '45',
#   'star_cast': 'Olivier Nakache (dir.), François Cluzet, Omar Sy',
#   'rating': '8.46891090054734',
#   'link': '/title/tt1675434/'},
#  {'movie_title': 'Whiplash',
#   'year': '2014',
#   'ranking': '46',
#   'star_cast': 'Damien Chazelle (dir.), Miles Teller, J.K. Simmons',
#   'rating': '8.468206057124732',
#   'link': '/title/tt2582802/'},
#  {'movie_title': 'The Prestige',
#   'year': '2006',
#   'ranking': '47',
#   'star_cast': 'Christopher Nolan (dir.), Christian Bale, Hugh Jackman',
#   'rating': '8.459837293845833',
#   'link': '/title/tt0482571/'},
#  {'movie_title': 'Grave of the Fireflies',
#   'year': '1988',
#   'ranking': '48',
#   'star_cast': 'Isao Takahata (dir.), Tsutomu Tatsumi, Ayano Shiraishi',
#   'rating': '8.455726902330412',
#   'link': '/title/tt0095327/'},
#  {'movie_title': 'Once Upon a Time in the West',
#   'year': '1968',
#   'ranking': '49',
#   'star_cast': 'Sergio Leone (dir.), Henry Fonda, Charles Bronson',
#   'rating': '8.449403617459474',
#   'link': '/title/tt0064116/'},
#  {'movie_title': 'Casablanca',
#   'year': '1942',
#   'ranking': '50',
#   'star_cast': 'Michael Curtiz (dir.), Humphrey Bogart, Ingrid Bergman',
#   'rating': '8.438442576452935',
#   'link': '/title/tt0034583/'},
#  {'movie_title': 'Cinema Paradiso',
#   'year': '1988',
#   'ranking': '51',
#   'star_cast': 'Giuseppe Tornatore (dir.), Philippe Noiret, Enzo Cannavale',
#   'rating': '8.431092257372343',
#   'link': '/title/tt0095765/'},
#  {'movie_title': 'Rear Window',
#   'year': '1954',
#   'ranking': '52',
#   'star_cast': 'Alfred Hitchcock (dir.), James Stewart, Grace Kelly',
#   'rating': '8.42743884709241',
#   'link': '/title/tt0047396/'},
#  {'movie_title': 'Alien',
#   'year': '1979',
#   'ranking': '53',
#   'star_cast': 'Ridley Scott (dir.), Sigourney Weaver, Tom Skerritt',
#   'rating': '8.421654886304212',
#   'link': '/title/tt0078748/'},
#  {'movie_title': 'Apocalypse Now',
#   'year': '1979',
#   'ranking': '54',
#   'star_cast': 'Francis Ford Coppola (dir.), Martin Sheen, Marlon Brando',
#   'rating': '8.419382011897937',
#   'link': '/title/tt0078788/'},
#  {'movie_title': 'Memento',
#   'year': '2000',
#   'ranking': '55',
#   'star_cast': 'Christopher Nolan (dir.), Guy Pearce, Carrie-Anne Moss',
#   'rating': '8.414671479667533',
#   'link': '/title/tt0209144/'},
#  {'movie_title': 'Raiders of the Lost Ark',
#   'year': '1981',
#   'ranking': '56',
#   'star_cast': 'Steven Spielberg (dir.), Harrison Ford, Karen Allen',
#   'rating': '8.410606200762606',
#   'link': '/title/tt0082971/'},
#  {'movie_title': 'The Great Dictator',
#   'year': '1940',
#   'ranking': '57',
#   'star_cast': 'Charles Chaplin (dir.), Charles Chaplin, Paulette Goddard',
#   'rating': '8.410135159655573',
#   'link': '/title/tt0032553/'},
#  {'movie_title': 'Joker',
#   'year': '2019',
#   'ranking': '58',
#   'star_cast': 'Todd Phillips (dir.), Joaquin Phoenix, Robert De Niro',
#   'rating': '8.391213815526774',
#   'link': '/title/tt7286456/'},
#  {'movie_title': 'Django Unchained',
#   'year': '2012',
#   'ranking': '59',
#   'star_cast': 'Quentin Tarantino (dir.), Jamie Foxx, Christoph Waltz',
#   'rating': '8.391205285933783',
#   'link': '/title/tt1853728/'},
#  {'movie_title': 'The Lives of Others',
#   'year': '2006',
#   'ranking': '60',
#   'star_cast': 'Florian Henckel von Donnersmarck (dir.), Ulrich Mühe, Martina Gedeck',
#   'rating': '8.390361979423593',
#   'link': '/title/tt0405094/'},
#  {'movie_title': 'Paths of Glory',
#   'year': '1957',
#   'ranking': '61',
#   'star_cast': 'Stanley Kubrick (dir.), Kirk Douglas, Ralph Meeker',
#   'rating': '8.375781814636925',
#   'link': '/title/tt0050825/'},
#  {'movie_title': 'WALL·E',
#   'year': '2008',
#   'ranking': '62',
#   'star_cast': 'Andrew Stanton (dir.), Ben Burtt, Elissa Knight',
#   'rating': '8.368574678878339',
#   'link': '/title/tt0910970/'},
#  {'movie_title': 'The Shining',
#   'year': '1980',
#   'ranking': '63',
#   'star_cast': 'Stanley Kubrick (dir.), Jack Nicholson, Shelley Duvall',
#   'rating': '8.36822452527682',
#   'link': '/title/tt0081505/'},
#  {'movie_title': 'Avengers: Infinity War',
#   'year': '2018',
#   'ranking': '64',
#   'star_cast': 'Anthony Russo (dir.), Robert Downey Jr., Chris Hemsworth',
#   'rating': '8.365501396015102',
#   'link': '/title/tt4154756/'},
#  {'movie_title': 'Sunset Blvd',
#   'year': '1950',
#   'ranking': '65',
#   'star_cast': 'Billy Wilder (dir.), William Holden, Gloria Swanson',
#   'rating': '8.360437311769866',
#   'link': '/title/tt0043014/'},
#  {'movie_title': 'Witness for the Prosecution',
#   'year': '1957',
#   'ranking': '66',
#   'star_cast': 'Billy Wilder (dir.), Tyrone Power, Marlene Dietrich',
#   'rating': '8.353053708770169',
#   'link': '/title/tt0051201/'},
#  {'movie_title': 'Spider-Man: Into the Spider-Verse',
#   'year': '2018',
#   'ranking': '67',
#   'star_cast': 'Bob Persichetti (dir.), Shameik Moore, Jake Johnson',
#   'rating': '8.351950515053618',
#   'link': '/title/tt4633694/'},
#  {'movie_title': 'Princess Mononoke',
#   'year': '1997',
#   'ranking': '68',
#   'star_cast': 'Hayao Miyazaki (dir.), Yôji Matsuda, Yuriko Ishida',
#   'rating': '8.351364161643735',
#   'link': '/title/tt0119698/'},
#  {'movie_title': 'Oldboy',
#   'year': '2003',
#   'ranking': '69',
#   'star_cast': 'Chan-wook Park (dir.), Min-sik Choi, Ji-Tae Yoo',
#   'rating': '8.351118859915085',
#   'link': '/title/tt0364569/'},
#  {'movie_title': 'Dr Strangelove or: How I Learned to Stop Worrying and Love the Bomb',
#   'year': '1964',
#   'ranking': '70',
#   'star_cast': 'Stanley Kubrick (dir.), Peter Sellers, George C. Scott',
#   'rating': '8.350484047457824',
#   'link': '/title/tt0057012/'},
#  {'movie_title': 'The Dark Knight Rises',
#   'year': '2012',
#   'ranking': '71',
#   'star_cast': 'Christopher Nolan (dir.), Christian Bale, Tom Hardy',
#   'rating': '8.333194596004951',
#   'link': '/title/tt1345836/'},
#  {'movie_title': 'Once Upon a Time in America',
#   'year': '1984',
#   'ranking': '72',
#   'star_cast': 'Sergio Leone (dir.), Robert De Niro, James Woods',
#   'rating': '8.331478787144118',
#   'link': '/title/tt0087843/'},
#  {'movie_title': 'Aliens',
#   'year': '1986',
#   'ranking': '73',
#   'star_cast': 'James Cameron (dir.), Sigourney Weaver, Michael Biehn',
#   'rating': '8.323918153573695',
#   'link': '/title/tt0090605/'},
#  {'movie_title': 'Avengers: Endgame',
#   'year': '2019',
#   'ranking': '74',
#   'star_cast': 'Anthony Russo (dir.), Robert Downey Jr., Chris Evans',
#   'rating': '8.320864811143935',
#   'link': '/title/tt4154796/'},
#  {'movie_title': 'Your Name',
#   'year': '2016',
#   'ranking': '75',
#   'star_cast': 'Makoto Shinkai (dir.), Ryûnosuke Kamiki, Mone Kamishiraishi',
#   'rating': '8.320244869373848',
#   'link': '/title/tt5311514/'},
#  {'movie_title': 'Coco',
#   'year': '2017',
#   'ranking': '76',
#   'star_cast': 'Lee Unkrich (dir.), Anthony Gonzalez, Gael García Bernal',
#   'rating': '8.314377004460063',
#   'link': '/title/tt2380307/'},
#  {'movie_title': 'American Beauty',
#   'year': '1999',
#   'ranking': '77',
#   'star_cast': 'Sam Mendes (dir.), Kevin Spacey, Annette Bening',
#   'rating': '8.30733913476376',
#   'link': '/title/tt0169547/'},
#  {'movie_title': 'Braveheart',
#   'year': '1995',
#   'ranking': '78',
#   'star_cast': 'Mel Gibson (dir.), Mel Gibson, Sophie Marceau',
#   'rating': '8.30272471886104',
#   'link': '/title/tt0112573/'},
#  {'movie_title': '3 Idiots',
#   'year': '2009',
#   'ranking': '79',
#   'star_cast': 'Rajkumar Hirani (dir.), Aamir Khan, Madhavan',
#   'rating': '8.300568967089658',
#   'link': '/title/tt1187043/'},
#  {'movie_title': 'Das Boot',
#   'year': '1981',
#   'ranking': '80',
#   'star_cast': 'Wolfgang Petersen (dir.), Jürgen Prochnow, Herbert Grönemeyer',
#   'rating': '8.29923695040235',
#   'link': '/title/tt0082096/'},
#  {'movie_title': 'Toy Story',
#   'year': '1995',
#   'ranking': '81',
#   'star_cast': 'John Lasseter (dir.), Tom Hanks, Tim Allen',
#   'rating': '8.296460255799118',
#   'link': '/title/tt0114709/'},
#  {'movie_title': 'High and Low',
#   'year': '1963',
#   'ranking': '82',
#   'star_cast': 'Akira Kurosawa (dir.), Toshirô Mifune, Yutaka Sada',
#   'rating': '8.294253913906253',
#   'link': '/title/tt0057565/'},
#  {'movie_title': 'Amadeus',
#   'year': '1984',
#   'ranking': '83',
#   'star_cast': 'Milos Forman (dir.), F. Murray Abraham, Tom Hulce',
#   'rating': '8.290024016876696',
#   'link': '/title/tt0086879/'},
#  {'movie_title': 'Taare Zameen Par',
#   'year': '2007',
#   'ranking': '84',
#   'star_cast': 'Aamir Khan (dir.), Darsheel Safary, Aamir Khan',
#   'rating': '8.2871934652648',
#   'link': '/title/tt0986264/'},
#  {'movie_title': 'Star Wars: Episode VI - Return of the Jedi',
#   'year': '1983',
#   'ranking': '85',
#   'star_cast': 'Richard Marquand (dir.), Mark Hamill, Harrison Ford',
#   'rating': '8.285600169248154',
#   'link': '/title/tt0086190/'},
#  {'movie_title': 'Capharnaüm',
#   'year': '2018',
#   'ranking': '86',
#   'star_cast': 'Nadine Labaki (dir.), Zain Al Rafeea, Yordanos Shiferaw',
#   'rating': '8.285230402836143',
#   'link': '/title/tt8267604/'},
#  {'movie_title': 'Inglourious Basterds',
#   'year': '2009',
#   'ranking': '87',
#   'star_cast': 'Quentin Tarantino (dir.), Brad Pitt, Diane Kruger',
#   'rating': '8.284857594860625',
#   'link': '/title/tt0361748/'},
#  {'movie_title': 'Reservoir Dogs',
#   'year': '1992',
#   'ranking': '88',
#   'star_cast': 'Quentin Tarantino (dir.), Harvey Keitel, Tim Roth',
#   'rating': '8.281457871411554',
#   'link': '/title/tt0105236/'},
#  {'movie_title': 'Good Will Hunting',
#   'year': '1997',
#   'ranking': '89',
#   'star_cast': 'Gus Van Sant (dir.), Robin Williams, Matt Damon',
#   'rating': '8.280444567917215',
#   'link': '/title/tt0119217/'},
#  {'movie_title': '2001: A Space Odyssey',
#   'year': '1968',
#   'ranking': '90',
#   'star_cast': 'Stanley Kubrick (dir.), Keir Dullea, Gary Lockwood',
#   'rating': '8.271156505404111',
#   'link': '/title/tt0062622/'},
#  {'movie_title': 'Requiem for a Dream',
#   'year': '2000',
#   'ranking': '91',
#   'star_cast': 'Darren Aronofsky (dir.), Ellen Burstyn, Jared Leto',
#   'rating': '8.267295620851042',
#   'link': '/title/tt0180093/'},
#  {'movie_title': 'Vertigo',
#   'year': '1958',
#   'ranking': '92',
#   'star_cast': 'Alfred Hitchcock (dir.), James Stewart, Kim Novak',
#   'rating': '8.265288629254655',
#   'link': '/title/tt0052357/'},
#  {'movie_title': 'M',
#   'year': '1931',
#   'ranking': '93',
#   'star_cast': 'Fritz Lang (dir.), Peter Lorre, Ellen Widmann',
#   'rating': '8.263239376707764',
#   'link': '/title/tt0022100/'},
#  {'movie_title': 'Dangal',
#   'year': '2016',
#   'ranking': '94',
#   'star_cast': 'Nitesh Tiwari (dir.), Aamir Khan, Sakshi Tanwar',
#   'rating': '8.261011193226631',
#   'link': '/title/tt5074352/'},
#  {'movie_title': 'Eternal Sunshine of the Spotless Mind',
#   'year': '2004',
#   'ranking': '95',
#   'star_cast': 'Michel Gondry (dir.), Jim Carrey, Kate Winslet',
#   'rating': '8.259517542507476',
#   'link': '/title/tt0338013/'},
#  {'movie_title': 'The Hunt',
#   'year': '2012',
#   'ranking': '96',
#   'star_cast': 'Thomas Vinterberg (dir.), Mads Mikkelsen, Thomas Bo Larsen',
#   'rating': '8.257915087022834',
#   'link': '/title/tt2106476/'},
#  {'movie_title': '1917',
#   'year': '2019',
#   'ranking': '97',
#   'star_cast': 'Sam Mendes (dir.), Dean-Charles Chapman, George MacKay',
#   'rating': '8.255900163352983',
#   'link': '/title/tt8579674/'},
#  {'movie_title': 'Citizen Kane',
#   'year': '1941',
#   'ranking': '98',
#   'star_cast': 'Orson Welles (dir.), Orson Welles, Joseph Cotten',
#   'rating': '8.254930176723704',
#   'link': '/title/tt0033467/'},
#  {'movie_title': 'Full Metal Jacket',
#   'year': '1987',
#   'ranking': '99',
#   'star_cast': 'Stanley Kubrick (dir.), Matthew Modine, R. Lee Ermey',
#   'rating': '8.248984560340899',
#   'link': '/title/tt0093058/'},
#  {'movie_title': ' Bicycle Thieves',
#   'year': '1948',
#   'ranking': '10',
#   'star_cast': 'Vittorio De Sica (dir.), Lamberto Maggiorani, Enzo Staiola',
#   'rating': '8.247737146858642',
#   'link': '/title/tt0040522/'},
#  {'movie_title': 'The Kid',
#   'year': '1921',
#   'ranking': '101',
#   'star_cast': 'Charles Chaplin (dir.), Charles Chaplin, Edna Purviance',
#   'rating': '8.246530735872563',
#   'link': '/title/tt0012349/'},
#  {'movie_title': 'A Clockwork Orange',
#   'year': '1971',
#   'ranking': '102',
#   'star_cast': 'Stanley Kubrick (dir.), Malcolm McDowell, Patrick Magee',
#   'rating': '8.245642991582187',
#   'link': '/title/tt0066921/'},
#  {'movie_title': 'North by Northwest',
#   'year': '1959',
#   'ranking': '103',
#   'star_cast': 'Alfred Hitchcock (dir.), Cary Grant, Eva Marie Saint',
#   'rating': '8.245345175864037',
#   'link': '/title/tt0053125/'},
#  {'movie_title': "Singin' in the Rain",
#   'year': '1952',
#   'ranking': '104',
#   'star_cast': "Stanley Donen (dir.), Gene Kelly, Donald O'Connor",
#   'rating': '8.24524941727597',
#   'link': '/title/tt0045152/'},
#  {'movie_title': 'Snatch',
#   'year': '2000',
#   'ranking': '105',
#   'star_cast': 'Guy Ritchie (dir.), Jason Statham, Brad Pitt',
#   'rating': '8.244501348019737',
#   'link': '/title/tt0208092/'},
#  {'movie_title': 'Scarface',
#   'year': '1983',
#   'ranking': '106',
#   'star_cast': 'Brian De Palma (dir.), Al Pacino, Michelle Pfeiffer',
#   'rating': '8.242287857182864',
#   'link': '/title/tt0086250/'},
#  {'movie_title': 'Taxi Driver',
#   'year': '1976',
#   'ranking': '107',
#   'star_cast': 'Martin Scorsese (dir.), Robert De Niro, Jodie Foster',
#   'rating': '8.239191758387117',
#   'link': '/title/tt0075314/'},
#  {'movie_title': 'Ikiru',
#   'year': '1952',
#   'ranking': '108',
#   'star_cast': 'Akira Kurosawa (dir.), Takashi Shimura, Nobuo Kaneko',
#   'rating': '8.235833213559877',
#   'link': '/title/tt0044741/'},
#  {'movie_title': 'Lawrence of Arabia',
#   'year': '1962',
#   'ranking': '109',
#   'star_cast': "David Lean (dir.), Peter O'Toole, Alec Guinness",
#   'rating': '8.234477746299177',
#   'link': '/title/tt0056172/'},
#  {'movie_title': 'Amélie',
#   'year': '2001',
#   'ranking': '110',
#   'star_cast': 'Jean-Pierre Jeunet (dir.), Audrey Tautou, Mathieu Kassovitz',
#   'rating': '8.234144920811376',
#   'link': '/title/tt0211915/'},
#  {'movie_title': 'Toy Story 3',
#   'year': '2010',
#   'ranking': '111',
#   'star_cast': 'Lee Unkrich (dir.), Tom Hanks, Tim Allen',
#   'rating': '8.23373177280922',
#   'link': '/title/tt0435761/'},
#  {'movie_title': 'The Sting',
#   'year': '1973',
#   'ranking': '112',
#   'star_cast': 'George Roy Hill (dir.), Paul Newman, Robert Redford',
#   'rating': '8.232370923618143',
#   'link': '/title/tt0070735/'},
#  {'movie_title': 'Metropolis',
#   'year': '1927',
#   'ranking': '113',
#   'star_cast': 'Fritz Lang (dir.), Brigitte Helm, Alfred Abel',
#   'rating': '8.23195173980935',
#   'link': '/title/tt0017136/'},
#  {'movie_title': 'A Separation',
#   'year': '2011',
#   'ranking': '114',
#   'star_cast': 'Asghar Farhadi (dir.), Payman Maadi, Leila Hatami',
#   'rating': '8.231517755247522',
#   'link': '/title/tt1832382/'},
#  {'movie_title': 'Incendies',
#   'year': '2010',
#   'ranking': '115',
#   'star_cast': 'Denis Villeneuve (dir.), Lubna Azabal, Mélissa Désormeaux-Poulin',
#   'rating': '8.227327084316075',
#   'link': '/title/tt1255953/'},
#  {'movie_title': 'For a Few Dollars More',
#   'year': '1965',
#   'ranking': '116',
#   'star_cast': 'Sergio Leone (dir.), Clint Eastwood, Lee Van Cleef',
#   'rating': '8.227300092982981',
#   'link': '/title/tt0059578/'},
#  {'movie_title': 'The Apartment',
#   'year': '1960',
#   'ranking': '117',
#   'star_cast': 'Billy Wilder (dir.), Jack Lemmon, Shirley MacLaine',
#   'rating': '8.22282738621212',
#   'link': '/title/tt0053604/'},
#  {'movie_title': 'Come and See',
#   'year': '1985',
#   'ranking': '118',
#   'star_cast': 'Elem Klimov (dir.), Aleksey Kravchenko, Olga Mironova',
#   'rating': '8.22217537356159',
#   'link': '/title/tt0091251/'},
#  {'movie_title': 'Double Indemnity',
#   'year': '1944',
#   'ranking': '119',
#   'star_cast': 'Billy Wilder (dir.), Fred MacMurray, Barbara Stanwyck',
#   'rating': '8.221054755123662',
#   'link': '/title/tt0036775/'},
#  {'movie_title': 'To Kill a Mockingbird',
#   'year': '1962',
#   'ranking': '120',
#   'star_cast': 'Robert Mulligan (dir.), Gregory Peck, John Megna',
#   'rating': '8.215520894746055',
#   'link': '/title/tt0056592/'},
#  {'movie_title': 'Up',
#   'year': '2009',
#   'ranking': '121',
#   'star_cast': 'Pete Docter (dir.), Edward Asner, Jordan Nagai',
#   'rating': '8.211412549203375',
#   'link': '/title/tt1049413/'},
#  {'movie_title': 'Indiana Jones and the Last Crusade',
#   'year': '1989',
#   'ranking': '122',
#   'star_cast': 'Steven Spielberg (dir.), Harrison Ford, Sean Connery',
#   'rating': '8.211313636297499',
#   'link': '/title/tt0097576/'},
#  {'movie_title': 'LA Confidential',
#   'year': '1997',
#   'ranking': '123',
#   'star_cast': 'Curtis Hanson (dir.), Kevin Spacey, Russell Crowe',
#   'rating': '8.202296448916627',
#   'link': '/title/tt0119488/'},
#  {'movie_title': 'Heat',
#   'year': '1995',
#   'ranking': '124',
#   'star_cast': 'Michael Mann (dir.), Al Pacino, Robert De Niro',
#   'rating': '8.20193532096205',
#   'link': '/title/tt0113277/'},
#  {'movie_title': 'Monty Python and the Holy Grail',
#   'year': '1975',
#   'ranking': '125',
#   'star_cast': 'Terry Gilliam (dir.), Graham Chapman, John Cleese',
#   'rating': '8.194480592194285',
#   'link': '/title/tt0071853/'},
#  {'movie_title': 'Die Hard',
#   'year': '1988',
#   'ranking': '126',
#   'star_cast': 'John McTiernan (dir.), Bruce Willis, Alan Rickman',
#   'rating': '8.194294432306917',
#   'link': '/title/tt0095016/'},
#  {'movie_title': 'Rashômon',
#   'year': '1950',
#   'ranking': '127',
#   'star_cast': 'Akira Kurosawa (dir.), Toshirô Mifune, Machiko Kyô',
#   'rating': '8.191262347411449',
#   'link': '/title/tt0042876/'},
#  {'movie_title': 'Batman Begins',
#   'year': '2005',
#   'ranking': '128',
#   'star_cast': 'Christopher Nolan (dir.), Christian Bale, Michael Caine',
#   'rating': '8.190096905508964',
#   'link': '/title/tt0372784/'},
#  {'movie_title': 'Yojimbo',
#   'year': '1961',
#   'ranking': '129',
#   'star_cast': 'Akira Kurosawa (dir.), Toshirô Mifune, Eijirô Tôno',
#   'rating': '8.189943576302468',
#   'link': '/title/tt0055630/'},
#  {'movie_title': 'Green Book',
#   'year': '2018',
#   'ranking': '130',
#   'star_cast': 'Peter Farrelly (dir.), Viggo Mortensen, Mahershala Ali',
#   'rating': '8.188331018160152',
#   'link': '/title/tt6966692/'},
#  {'movie_title': 'Children of Heaven',
#   'year': '1997',
#   'ranking': '131',
#   'star_cast': 'Majid Majidi (dir.), Mohammad Amir Naji, Amir Farrokh Hashemian',
#   'rating': '8.185547303760096',
#   'link': '/title/tt0118849/'},
#  {'movie_title': 'Downfall',
#   'year': '2004',
#   'ranking': '132',
#   'star_cast': 'Oliver Hirschbiegel (dir.), Bruno Ganz, Alexandra Maria Lara',
#   'rating': '8.185373341443983',
#   'link': '/title/tt0363163/'},
#  {'movie_title': 'Unforgiven',
#   'year': '1992',
#   'ranking': '133',
#   'star_cast': 'Clint Eastwood (dir.), Clint Eastwood, Gene Hackman',
#   'rating': '8.180417772432268',
#   'link': '/title/tt0105695/'},
#  {'movie_title': 'Some Like It Hot',
#   'year': '1959',
#   'ranking': '134',
#   'star_cast': 'Billy Wilder (dir.), Marilyn Monroe, Tony Curtis',
#   'rating': '8.176093083175992',
#   'link': '/title/tt0053291/'},
#  {'movie_title': 'Ran',
#   'year': '1985',
#   'ranking': '135',
#   'star_cast': 'Akira Kurosawa (dir.), Tatsuya Nakadai, Akira Terao',
#   'rating': '8.175733337651934',
#   'link': '/title/tt0089881/'},
#  {'movie_title': "Howl's Moving Castle",
#   'year': '2004',
#   'ranking': '136',
#   'star_cast': 'Hayao Miyazaki (dir.), Chieko Baishô, Takuya Kimura',
#   'rating': '8.166209395166195',
#   'link': '/title/tt0347149/'},
#  {'movie_title': 'Anand',
#   'year': '1971',
#   'ranking': '137',
#   'star_cast': 'Hrishikesh Mukherjee (dir.), Rajesh Khanna, Amitabh Bachchan',
#   'rating': '8.162812644673155',
#   'link': '/title/tt0066763/'},
#  {'movie_title': 'A Beautiful Mind',
#   'year': '2001',
#   'ranking': '138',
#   'star_cast': 'Ron Howard (dir.), Russell Crowe, Ed Harris',
#   'rating': '8.160699718053614',
#   'link': '/title/tt0268978/'},
#  {'movie_title': 'All About Eve',
#   'year': '1950',
#   'ranking': '139',
#   'star_cast': 'Joseph L. Mankiewicz (dir.), Bette Davis, Anne Baxter',
#   'rating': '8.159964944777343',
#   'link': '/title/tt0042192/'},
#  {'movie_title': 'The Great Escape',
#   'year': '1963',
#   'ranking': '140',
#   'star_cast': 'John Sturges (dir.), Steve McQueen, James Garner',
#   'rating': '8.159860741149002',
#   'link': '/title/tt0057115/'},
#  {'movie_title': 'Casino',
#   'year': '1995',
#   'ranking': '141',
#   'star_cast': 'Martin Scorsese (dir.), Robert De Niro, Sharon Stone',
#   'rating': '8.159815251372516',
#   'link': '/title/tt0112641/'},
#  {'movie_title': 'The Wolf of Wall Street',
#   'year': '2013',
#   'ranking': '142',
#   'star_cast': 'Martin Scorsese (dir.), Leonardo DiCaprio, Jonah Hill',
#   'rating': '8.154539512653717',
#   'link': '/title/tt0993846/'},
#  {'movie_title': "Pan's Labyrinth",
#   'year': '2006',
#   'ranking': '143',
#   'star_cast': 'Guillermo del Toro (dir.), Ivana Baquero, Ariadna Gil',
#   'rating': '8.154508750724817',
#   'link': '/title/tt0457430/'},
#  {'movie_title': 'The Secret in Their Eyes',
#   'year': '2009',
#   'ranking': '144',
#   'star_cast': 'Juan José Campanella (dir.), Ricardo Darín, Soledad Villamil',
#   'rating': '8.149902425729161',
#   'link': '/title/tt1305806/'},
#  {'movie_title': 'Lock, Stock and Two Smoking Barrels',
#   'year': '1998',
#   'ranking': '145',
#   'star_cast': 'Guy Ritchie (dir.), Jason Flemyng, Dexter Fletcher',
#   'rating': '8.148242971447024',
#   'link': '/title/tt0120735/'},
#  {'movie_title': 'Raging Bull',
#   'year': '1980',
#   'ranking': '146',
#   'star_cast': 'Martin Scorsese (dir.), Robert De Niro, Cathy Moriarty',
#   'rating': '8.146585038454138',
#   'link': '/title/tt0081398/'},
#  {'movie_title': 'My Neighbor Totoro',
#   'year': '1988',
#   'ranking': '147',
#   'star_cast': 'Hayao Miyazaki (dir.), Hitoshi Takagi, Noriko Hidaka',
#   'rating': '8.146252646862036',
#   'link': '/title/tt0096283/'},
#  {'movie_title': 'There Will Be Blood',
#   'year': '2007',
#   'ranking': '148',
#   'star_cast': 'Paul Thomas Anderson (dir.), Daniel Day-Lewis, Paul Dano',
#   'rating': '8.145240919111503',
#   'link': '/title/tt0469494/'},
#  {'movie_title': 'Judgment at Nuremberg',
#   'year': '1961',
#   'ranking': '149',
#   'star_cast': 'Stanley Kramer (dir.), Spencer Tracy, Burt Lancaster',
#   'rating': '8.14063756739061',
#   'link': '/title/tt0055031/'},
#  {'movie_title': 'The Treasure of the Sierra Madre',
#   'year': '1948',
#   'ranking': '150',
#   'star_cast': 'John Huston (dir.), Humphrey Bogart, Walter Huston',
#   'rating': '8.13931603634859',
#   'link': '/title/tt0040897/'},
#  {'movie_title': 'Three Billboards Outside Ebbing, Missouri',
#   'year': '2017',
#   'ranking': '151',
#   'star_cast': 'Martin McDonagh (dir.), Frances McDormand, Woody Harrelson',
#   'rating': '8.131757164250171',
#   'link': '/title/tt5027774/'},
#  {'movie_title': 'Dial M for Murder',
#   'year': '1954',
#   'ranking': '152',
#   'star_cast': 'Alfred Hitchcock (dir.), Ray Milland, Grace Kelly',
#   'rating': '8.131019287696601',
#   'link': '/title/tt0046912/'},
#  {'movie_title': 'Babam ve Oglum',
#   'year': '2005',
#   'ranking': '153',
#   'star_cast': 'Çagan Irmak (dir.), Çetin Tekindor, Fikret Kuskan',
#   'rating': '8.12948302848989',
#   'link': '/title/tt0476735/'},
#  {'movie_title': 'Chinatown',
#   'year': '1974',
#   'ranking': '154',
#   'star_cast': 'Roman Polanski (dir.), Jack Nicholson, Faye Dunaway',
#   'rating': '8.129085092789122',
#   'link': '/title/tt0071315/'},
#  {'movie_title': 'The Gold Rush',
#   'year': '1925',
#   'ranking': '155',
#   'star_cast': 'Charles Chaplin (dir.), Charles Chaplin, Mack Swain',
#   'rating': '8.128822789083532',
#   'link': '/title/tt0015864/'},
#  {'movie_title': 'Shutter Island',
#   'year': '2010',
#   'ranking': '156',
#   'star_cast': 'Martin Scorsese (dir.), Leonardo DiCaprio, Emily Mortimer',
#   'rating': '8.125862672847399',
#   'link': '/title/tt1130884/'},
#  {'movie_title': 'No Country for Old Men',
#   'year': '2007',
#   'ranking': '157',
#   'star_cast': 'Ethan Coen (dir.), Tommy Lee Jones, Javier Bardem',
#   'rating': '8.124584622446593',
#   'link': '/title/tt0477348/'},
#  {'movie_title': 'V for Vendetta',
#   'year': '2005',
#   'ranking': '158',
#   'star_cast': 'James McTeigue (dir.), Hugo Weaving, Natalie Portman',
#   'rating': '8.124441898924172',
#   'link': '/title/tt0434409/'},
#  {'movie_title': 'The Seventh Seal',
#   'year': '1957',
#   'ranking': '159',
#   'star_cast': 'Ingmar Bergman (dir.), Max von Sydow, Gunnar Björnstrand',
#   'rating': '8.121628544145025',
#   'link': '/title/tt0050976/'},
#  {'movie_title': 'Inside Out',
#   'year': '2015',
#   'ranking': '160',
#   'star_cast': 'Pete Docter (dir.), Amy Poehler, Bill Hader',
#   'rating': '8.121066413204453',
#   'link': '/title/tt2096673/'},
#  {'movie_title': 'Warrior',
#   'year': '2011',
#   'ranking': '161',
#   'star_cast': "Gavin O'Connor (dir.), Tom Hardy, Nick Nolte",
#   'rating': '8.119251726237007',
#   'link': '/title/tt1291584/'},
#  {'movie_title': 'The Elephant Man',
#   'year': '1980',
#   'ranking': '162',
#   'star_cast': 'David Lynch (dir.), Anthony Hopkins, John Hurt',
#   'rating': '8.116804266097208',
#   'link': '/title/tt0080678/'},
#  {'movie_title': 'Trainspotting',
#   'year': '1996',
#   'ranking': '163',
#   'star_cast': 'Danny Boyle (dir.), Ewan McGregor, Ewen Bremner',
#   'rating': '8.115935806485602',
#   'link': '/title/tt0117951/'},
#  {'movie_title': 'The Sixth Sense',
#   'year': '1999',
#   'ranking': '164',
#   'star_cast': 'M. Night Shyamalan (dir.), Bruce Willis, Haley Joel Osment',
#   'rating': '8.11577497315709',
#   'link': '/title/tt0167404/'},
#  {'movie_title': 'The Thing',
#   'year': '1982',
#   'ranking': '165',
#   'star_cast': 'John Carpenter (dir.), Kurt Russell, Wilford Brimley',
#   'rating': '8.115548343226287',
#   'link': '/title/tt0084787/'},
#  {'movie_title': 'Jurassic Park',
#   'year': '1993',
#   'ranking': '166',
#   'star_cast': 'Steven Spielberg (dir.), Sam Neill, Laura Dern',
#   'rating': '8.11235004660508',
#   'link': '/title/tt0107290/'},
#  {'movie_title': 'Gone with the Wind',
#   'year': '1939',
#   'ranking': '167',
#   'star_cast': 'Victor Fleming (dir.), Clark Gable, Vivien Leigh',
#   'rating': '8.107636629216445',
#   'link': '/title/tt0031381/'},
#  {'movie_title': 'The Truman Show',
#   'year': '1998',
#   'ranking': '168',
#   'star_cast': 'Peter Weir (dir.), Jim Carrey, Ed Harris',
#   'rating': '8.10598950570668',
#   'link': '/title/tt0120382/'},
#  {'movie_title': 'Wild Strawberries',
#   'year': '1957',
#   'ranking': '169',
#   'star_cast': 'Ingmar Bergman (dir.), Victor Sjöström, Bibi Andersson',
#   'rating': '8.10520801072791',
#   'link': '/title/tt0050986/'},
#  {'movie_title': 'Finding Nemo',
#   'year': '2003',
#   'ranking': '170',
#   'star_cast': 'Andrew Stanton (dir.), Albert Brooks, Ellen DeGeneres',
#   'rating': '8.104804003402519',
#   'link': '/title/tt0266543/'},
#  {'movie_title': 'Blade Runner',
#   'year': '1982',
#   'ranking': '171',
#   'star_cast': 'Ridley Scott (dir.), Harrison Ford, Rutger Hauer',
#   'rating': '8.104309798573885',
#   'link': '/title/tt0083658/'},
#  {'movie_title': 'Stalker',
#   'year': '1979',
#   'ranking': '172',
#   'star_cast': 'Andrei Tarkovsky (dir.), Alisa Freyndlikh, Aleksandr Kaydanovskiy',
#   'rating': '8.102026202389094',
#   'link': '/title/tt0079944/'},
#  {'movie_title': 'Room',
#   'year': '2015',
#   'ranking': '173',
#   'star_cast': 'Lenny Abrahamson (dir.), Brie Larson, Jacob Tremblay',
#   'rating': '8.101619495592566',
#   'link': '/title/tt3170832/'},
#  {'movie_title': 'Kill Bill: Vol 1',
#   'year': '2003',
#   'ranking': '174',
#   'star_cast': 'Quentin Tarantino (dir.), Uma Thurman, David Carradine',
#   'rating': '8.101400651132304',
#   'link': '/title/tt0266697/'},
#  {'movie_title': 'The Bridge on the River Kwai',
#   'year': '1957',
#   'ranking': '175',
#   'star_cast': 'David Lean (dir.), William Holden, Alec Guinness',
#   'rating': '8.10112717866021',
#   'link': '/title/tt0050212/'},
#  {'movie_title': 'Fargo',
#   'year': '1996',
#   'ranking': '176',
#   'star_cast': 'Joel Coen (dir.), William H. Macy, Frances McDormand',
#   'rating': '8.099209343851241',
#   'link': '/title/tt0116282/'},
#  {'movie_title': 'Memories of Murder',
#   'year': '2003',
#   'ranking': '177',
#   'star_cast': 'Bong Joon Ho (dir.), Kang-ho Song, Sang-kyung Kim',
#   'rating': '8.097304158798735',
#   'link': '/title/tt0353969/'},
#  {'movie_title': 'Tokyo Story',
#   'year': '1953',
#   'ranking': '178',
#   'star_cast': 'Yasujirô Ozu (dir.), Chishû Ryû, Chieko Higashiyama',
#   'rating': '8.095894643105776',
#   'link': '/title/tt0046438/'},
#  {'movie_title': 'The Third Man',
#   'year': '1949',
#   'ranking': '179',
#   'star_cast': 'Carol Reed (dir.), Orson Welles, Joseph Cotten',
#   'rating': '8.095799078242228',
#   'link': '/title/tt0041959/'},
#  {'movie_title': 'Gran Torino',
#   'year': '2008',
#   'ranking': '180',
#   'star_cast': 'Clint Eastwood (dir.), Clint Eastwood, Bee Vang',
#   'rating': '8.094992151950505',
#   'link': '/title/tt1205489/'},
#  {'movie_title': 'On the Waterfront',
#   'year': '1954',
#   'ranking': '181',
#   'star_cast': 'Elia Kazan (dir.), Marlon Brando, Karl Malden',
#   'rating': '8.094979162305492',
#   'link': '/title/tt0047296/'},
#  {'movie_title': 'The Deer Hunter',
#   'year': '1978',
#   'ranking': '182',
#   'star_cast': 'Michael Cimino (dir.), Robert De Niro, Christopher Walken',
#   'rating': '8.092028060213364',
#   'link': '/title/tt0077416/'},
#  {'movie_title': 'Wild Tales',
#   'year': '2014',
#   'ranking': '183',
#   'star_cast': 'Damián Szifron (dir.), Darío Grandinetti, María Marull',
#   'rating': '8.091821863825059',
#   'link': '/title/tt3011894/'},
#  {'movie_title': 'Klaus',
#   'year': '2019',
#   'ranking': '184',
#   'star_cast': 'Sergio Pablos (dir.), Jason Schwartzman, J.K. Simmons',
#   'rating': '8.088012906870746',
#   'link': '/title/tt4729430/'},
#  {'movie_title': 'In the Name of the Father',
#   'year': '1993',
#   'ranking': '185',
#   'star_cast': 'Jim Sheridan (dir.), Daniel Day-Lewis, Pete Postlethwaite',
#   'rating': '8.085471099800705',
#   'link': '/title/tt0107207/'},
#  {'movie_title': 'Mary and Max',
#   'year': '2009',
#   'ranking': '186',
#   'star_cast': 'Adam Elliot (dir.), Toni Collette, Philip Seymour Hoffman',
#   'rating': '8.08456239978148',
#   'link': '/title/tt0978762/'},
#  {'movie_title': 'Andhadhun',
#   'year': '2018',
#   'ranking': '187',
#   'star_cast': 'Sriram Raghavan (dir.), Ayushmann Khurrana, Tabu',
#   'rating': '8.083915283856715',
#   'link': '/title/tt8108198/'},
#  {'movie_title': 'Gone Girl',
#   'year': '2014',
#   'ranking': '188',
#   'star_cast': 'David Fincher (dir.), Ben Affleck, Rosamund Pike',
#   'rating': '8.082107085321763',
#   'link': '/title/tt2267998/'},
#  {'movie_title': 'The Grand Budapest Hotel',
#   'year': '2014',
#   'ranking': '189',
#   'star_cast': 'Wes Anderson (dir.), Ralph Fiennes, F. Murray Abraham',
#   'rating': '8.081402194625676',
#   'link': '/title/tt2278388/'},
#  {'movie_title': 'Hacksaw Ridge',
#   'year': '2016',
#   'ranking': '190',
#   'star_cast': 'Mel Gibson (dir.), Andrew Garfield, Sam Worthington',
#   'rating': '8.081315482511881',
#   'link': '/title/tt2119532/'},
#  {'movie_title': 'Before Sunrise',
#   'year': '1995',
#   'ranking': '191',
#   'star_cast': 'Richard Linklater (dir.), Ethan Hawke, Julie Delpy',
#   'rating': '8.080150793142646',
#   'link': '/title/tt0112471/'},
#  {'movie_title': 'The Big Lebowski',
#   'year': '1998',
#   'ranking': '192',
#   'star_cast': 'Joel Coen (dir.), Jeff Bridges, John Goodman',
#   'rating': '8.078662701949412',
#   'link': '/title/tt0118715/'},
#  {'movie_title': 'Catch Me If You Can',
#   'year': '2002',
#   'ranking': '193',
#   'star_cast': 'Steven Spielberg (dir.), Leonardo DiCaprio, Tom Hanks',
#   'rating': '8.07845672008384',
#   'link': '/title/tt0264464/'},
#  {'movie_title': 'Persona',
#   'year': '1966',
#   'ranking': '194',
#   'star_cast': 'Ingmar Bergman (dir.), Bibi Andersson, Liv Ullmann',
#   'rating': '8.07673402778153',
#   'link': '/title/tt0060827/'},
#  {'movie_title': 'The Bandit',
#   'year': '1996',
#   'ranking': '195',
#   'star_cast': 'Yavuz Turgul (dir.), Sener Sen, Ugur Yücel',
#   'rating': '8.075651951551196',
#   'link': '/title/tt0116231/'},
#  {'movie_title': 'To Be or Not to Be',
#   'year': '1942',
#   'ranking': '196',
#   'star_cast': 'Ernst Lubitsch (dir.), Carole Lombard, Jack Benny',
#   'rating': '8.074678966651051',
#   'link': '/title/tt0035446/'},
#  {'movie_title': 'Prisoners',
#   'year': '2013',
#   'ranking': '197',
#   'star_cast': 'Denis Villeneuve (dir.), Hugh Jackman, Jake Gyllenhaal',
#   'rating': '8.07325890893987',
#   'link': '/title/tt1392214/'},
#  {'movie_title': 'Sherlock Jr',
#   'year': '1924',
#   'ranking': '198',
#   'star_cast': 'Buster Keaton (dir.), Buster Keaton, Kathryn McGuire',
#   'rating': '8.07239062905115',
#   'link': '/title/tt0015324/'},
#  {'movie_title': 'Ford v Ferrari',
#   'year': '2019',
#   'ranking': '199',
#   'star_cast': 'James Mangold (dir.), Matt Damon, Christian Bale',
#   'rating': '8.071882781132555',
#   'link': '/title/tt1950186/'},
#  {'movie_title': 'The General',
#   'year': '1926',
#   'ranking': '200',
#   'star_cast': 'Clyde Bruckman (dir.), Buster Keaton, Marion Mack',
#   'rating': '8.071528981072815',
#   'link': '/title/tt0017925/'},
#  {'movie_title': 'How to Train Your Dragon',
#   'year': '2010',
#   'ranking': '201',
#   'star_cast': 'Dean DeBlois (dir.), Jay Baruchel, Gerard Butler',
#   'rating': '8.071047050504058',
#   'link': '/title/tt0892769/'},
#  {'movie_title': 'Mr Smith Goes to Washington',
#   'year': '1939',
#   'ranking': '202',
#   'star_cast': 'Frank Capra (dir.), James Stewart, Jean Arthur',
#   'rating': '8.066683430283994',
#   'link': '/title/tt0031679/'},
#  {'movie_title': '12 Years a Slave',
#   'year': '2013',
#   'ranking': '203',
#   'star_cast': 'Steve McQueen (dir.), Chiwetel Ejiofor, Michael Kenneth Williams',
#   'rating': '8.065855110428192',
#   'link': '/title/tt2024544/'},
#  {'movie_title': 'Barry Lyndon',
#   'year': '1975',
#   'ranking': '204',
#   'star_cast': "Stanley Kubrick (dir.), Ryan O'Neal, Marisa Berenson",
#   'rating': '8.063494106916279',
#   'link': '/title/tt0072684/'},
#  {'movie_title': 'Mad Max: Fury Road',
#   'year': '2015',
#   'ranking': '205',
#   'star_cast': 'George Miller (dir.), Tom Hardy, Charlize Theron',
#   'rating': '8.061572430324917',
#   'link': '/title/tt1392190/'},
#  {'movie_title': 'Stand by Me',
#   'year': '1986',
#   'ranking': '206',
#   'star_cast': 'Rob Reiner (dir.), Wil Wheaton, River Phoenix',
#   'rating': '8.057148808681454',
#   'link': '/title/tt0092005/'},
#  {'movie_title': 'Network',
#   'year': '1976',
#   'ranking': '207',
#   'star_cast': 'Sidney Lumet (dir.), Faye Dunaway, William Holden',
#   'rating': '8.057133953560975',
#   'link': '/title/tt0074958/'},
#  {'movie_title': 'Million Dollar Baby',
#   'year': '2004',
#   'ranking': '208',
#   'star_cast': 'Clint Eastwood (dir.), Hilary Swank, Clint Eastwood',
#   'rating': '8.057093787512024',
#   'link': '/title/tt0405159/'},
#  {'movie_title': 'Cool Hand Luke',
#   'year': '1967',
#   'ranking': '209',
#   'star_cast': 'Stuart Rosenberg (dir.), Paul Newman, George Kennedy',
#   'rating': '8.055253354332208',
#   'link': '/title/tt0061512/'},
#  {'movie_title': 'Dead Poets Society',
#   'year': '1989',
#   'ranking': '210',
#   'star_cast': 'Peter Weir (dir.), Robin Williams, Robert Sean Leonard',
#   'rating': '8.053632342851895',
#   'link': '/title/tt0097165/'},
#  {'movie_title': "Hachi: A Dog's Tale",
#   'year': '2009',
#   'ranking': '211',
#   'star_cast': 'Lasse Hallström (dir.), Richard Gere, Joan Allen',
#   'rating': '8.05307276920685',
#   'link': '/title/tt1028532/'},
#  {'movie_title': 'Ben-Hur',
#   'year': '1959',
#   'ranking': '212',
#   'star_cast': 'William Wyler (dir.), Charlton Heston, Jack Hawkins',
#   'rating': '8.052890658494265',
#   'link': '/title/tt0052618/'},
#  {'movie_title': 'Harry Potter and the Deathly Hallows: Part 2',
#   'year': '2011',
#   'ranking': '213',
#   'star_cast': 'David Yates (dir.), Daniel Radcliffe, Emma Watson',
#   'rating': '8.051953032485489',
#   'link': '/title/tt1201607/'},
#  {'movie_title': 'Into the Wild',
#   'year': '2007',
#   'ranking': '214',
#   'star_cast': 'Sean Penn (dir.), Emile Hirsch, Vince Vaughn',
#   'rating': '8.051571342703507',
#   'link': '/title/tt0758758/'},
#  {'movie_title': 'Platoon',
#   'year': '1986',
#   'ranking': '215',
#   'star_cast': 'Oliver Stone (dir.), Charlie Sheen, Tom Berenger',
#   'rating': '8.05125842996753',
#   'link': '/title/tt0091763/'},
#  {'movie_title': 'Logan',
#   'year': '2017',
#   'ranking': '216',
#   'star_cast': 'James Mangold (dir.), Hugh Jackman, Patrick Stewart',
#   'rating': '8.050420947137965',
#   'link': '/title/tt3315342/'},
#  {'movie_title': 'The Wages of Fear',
#   'year': '1953',
#   'ranking': '217',
#   'star_cast': 'Henri-Georges Clouzot (dir.), Yves Montand, Charles Vanel',
#   'rating': '8.049620232181855',
#   'link': '/title/tt0046268/'},
#  {'movie_title': "Monty Python's Life of Brian",
#   'year': '1979',
#   'ranking': '218',
#   'star_cast': 'Terry Jones (dir.), Graham Chapman, John Cleese',
#   'rating': '8.049535067244436',
#   'link': '/title/tt0079470/'},
#  {'movie_title': 'Rush',
#   'year': '2013',
#   'ranking': '219',
#   'star_cast': 'Ron Howard (dir.), Daniel Brühl, Chris Hemsworth',
#   'rating': '8.049232839855586',
#   'link': '/title/tt1979320/'},
#  {'movie_title': 'The Handmaiden',
#   'year': '2016',
#   'ranking': '220',
#   'star_cast': 'Chan-wook Park (dir.), Min-hee Kim, Jung-woo Ha',
#   'rating': '8.047432246650878',
#   'link': '/title/tt4016934/'},
#  {'movie_title': 'The Passion of Joan of Arc',
#   'year': '1928',
#   'ranking': '221',
#   'star_cast': 'Carl Theodor Dreyer (dir.), Maria Falconetti, Eugene Silvain',
#   'rating': '8.044119083853586',
#   'link': '/title/tt0019254/'},
#  {'movie_title': 'The 400 Blows',
#   'year': '1959',
#   'ranking': '222',
#   'star_cast': 'François Truffaut (dir.), Jean-Pierre Léaud, Albert Rémy',
#   'rating': '8.043617100791732',
#   'link': '/title/tt0053198/'},
#  {'movie_title': 'Andrei Rublev',
#   'year': '1966',
#   'ranking': '223',
#   'star_cast': 'Andrei Tarkovsky (dir.), Anatoliy Solonitsyn, Ivan Lapikov',
#   'rating': '8.043261844181231',
#   'link': '/title/tt0060107/'},
#  {'movie_title': 'Hotel Rwanda',
#   'year': '2004',
#   'ranking': '224',
#   'star_cast': 'Terry George (dir.), Don Cheadle, Sophie Okonedo',
#   'rating': '8.04232493962767',
#   'link': '/title/tt0395169/'},
#  {'movie_title': 'Spotlight',
#   'year': '2015',
#   'ranking': '225',
#   'star_cast': 'Tom McCarthy (dir.), Mark Ruffalo, Michael Keaton',
#   'rating': '8.041348603703772',
#   'link': '/title/tt1895587/'},
#  {'movie_title': 'Rififi',
#   'year': '1955',
#   'ranking': '226',
#   'star_cast': 'Jules Dassin (dir.), Jean Servais, Carl Möhner',
#   'rating': '8.040901395861747',
#   'link': '/title/tt0048021/'},
#  {'movie_title': 'Amores Perros',
#   'year': '2000',
#   'ranking': '227',
#   'star_cast': 'Alejandro G. Iñárritu (dir.), Emilio Echevarría, Gael García Bernal',
#   'rating': '8.039819580945503',
#   'link': '/title/tt0245712/'},
#  {'movie_title': 'La Haine',
#   'year': '1995',
#   'ranking': '228',
#   'star_cast': 'Mathieu Kassovitz (dir.), Vincent Cassel, Hubert Koundé',
#   'rating': '8.037681652629791',
#   'link': '/title/tt0113247/'},
#  {'movie_title': 'Nausicaä of the Valley of the Wind',
#   'year': '1984',
#   'ranking': '229',
#   'star_cast': 'Hayao Miyazaki (dir.), Sumi Shimamoto, Mahito Tsujimura',
#   'rating': '8.035762327562026',
#   'link': '/title/tt0087544/'},
#  {'movie_title': 'Gangs of Wasseypur',
#   'year': '2012',
#   'ranking': '230',
#   'star_cast': 'Anurag Kashyap (dir.), Manoj Bajpayee, Richa Chadha',
#   'rating': '8.0354273606698',
#   'link': '/title/tt1954470/'},
#  {'movie_title': 'Rocky',
#   'year': '1976',
#   'ranking': '231',
#   'star_cast': 'John G. Avildsen (dir.), Sylvester Stallone, Talia Shire',
#   'rating': '8.035064915005563',
#   'link': '/title/tt0075148/'},
#  {'movie_title': 'Rang De Basanti',
#   'year': '2006',
#   'ranking': '232',
#   'star_cast': 'Rakeysh Omprakash Mehra (dir.), Aamir Khan, Soha Ali Khan',
#   'rating': '8.034060370176503',
#   'link': '/title/tt0405508/'},
#  {'movie_title': 'Monsters, Inc',
#   'year': '2001',
#   'ranking': '233',
#   'star_cast': 'Pete Docter (dir.), Billy Crystal, John Goodman',
#   'rating': '8.032674146140822',
#   'link': '/title/tt0198781/'},
#  {'movie_title': 'Rebecca',
#   'year': '1940',
#   'ranking': '234',
#   'star_cast': 'Alfred Hitchcock (dir.), Laurence Olivier, Joan Fontaine',
#   'rating': '8.031613522197636',
#   'link': '/title/tt0032976/'},
#  {'movie_title': 'Before Sunset',
#   'year': '2004',
#   'ranking': '235',
#   'star_cast': 'Richard Linklater (dir.), Ethan Hawke, Julie Delpy',
#   'rating': '8.021123082438583',
#   'link': '/title/tt0381681/'},
#  {'movie_title': 'Portrait of a Lady on Fire',
#   'year': '2019',
#   'ranking': '236',
#   'star_cast': 'Céline Sciamma (dir.), Noémie Merlant, Adèle Haenel',
#   'rating': '8.020584242077263',
#   'link': '/title/tt8613070/'},
#  {'movie_title': 'In the Mood for Love',
#   'year': '2000',
#   'ranking': '237',
#   'star_cast': 'Kar-Wai Wong (dir.), Tony Chiu-Wai Leung, Maggie Cheung',
#   'rating': '8.018476006574286',
#   'link': '/title/tt0118694/'},
#  {'movie_title': 'Drishyam',
#   'year': '2015',
#   'ranking': '238',
#   'star_cast': 'Nishikant Kamat (dir.), Ajay Devgn, Shriya Saran',
#   'rating': '8.016721381664444',
#   'link': '/title/tt4430212/'},
#  {'movie_title': 'Paris, Texas',
#   'year': '1984',
#   'ranking': '239',
#   'star_cast': 'Wim Wenders (dir.), Harry Dean Stanton, Nastassja Kinski',
#   'rating': '8.016690276713415',
#   'link': '/title/tt0087884/'},
#  {'movie_title': 'It Happened One Night',
#   'year': '1934',
#   'ranking': '240',
#   'star_cast': 'Frank Capra (dir.), Clark Gable, Claudette Colbert',
#   'rating': '8.01624839364069',
#   'link': '/title/tt0025316/'},
#  {'movie_title': 'The Invisible Guest',
#   'year': '2016',
#   'ranking': '241',
#   'star_cast': 'Oriol Paulo (dir.), Mario Casas, Ana Wagener',
#   'rating': '8.012760822549861',
#   'link': '/title/tt4857264/'},
#  {'movie_title': 'The Help',
#   'year': '2011',
#   'ranking': '242',
#   'star_cast': 'Tate Taylor (dir.), Emma Stone, Viola Davis',
#   'rating': '8.011778634577624',
#   'link': '/title/tt1454029/'},
#  {'movie_title': 'The Circus',
#   'year': '1928',
#   'ranking': '243',
#   'star_cast': 'Charles Chaplin (dir.), Charles Chaplin, Merna Kennedy',
#   'rating': '8.011672178192805',
#   'link': '/title/tt0018773/'},
#  {'movie_title': 'The Princess Bride',
#   'year': '1987',
#   'ranking': '244',
#   'star_cast': 'Rob Reiner (dir.), Cary Elwes, Mandy Patinkin',
#   'rating': '8.011280325036177',
#   'link': '/title/tt0093779/'},
#  {'movie_title': 'The Battle of Algiers',
#   'year': '1966',
#   'ranking': '245',
#   'star_cast': 'Gillo Pontecorvo (dir.), Brahim Hadjadj, Jean Martin',
#   'rating': '8.00979319560275',
#   'link': '/title/tt0058946/'},
#  {'movie_title': 'The Terminator',
#   'year': '1984',
#   'ranking': '246',
#   'star_cast': 'James Cameron (dir.), Arnold Schwarzenegger, Linda Hamilton',
#   'rating': '8.009027432599156',
#   'link': '/title/tt0088247/'},
#  {'movie_title': 'Tangerines',
#   'year': '2013',
#   'ranking': '247',
#   'star_cast': 'Zaza Urushadze (dir.), Lembit Ulfsak, Elmo Nüganen',
#   'rating': '8.008279594204877',
#   'link': '/title/tt2991224/'},
#  {'movie_title': 'Aladdin',
#   'year': '1992',
#   'ranking': '248',
#   'star_cast': 'Ron Clements (dir.), Scott Weinger, Robin Williams',
#   'rating': '8.007409185119814',
#   'link': '/title/tt0103639/'},
#  {'movie_title': 'Fanny and Alexander',
#   'year': '1982',
#   'ranking': '249',
#   'star_cast': 'Ingmar Bergman (dir.), Bertil Guve, Pernilla Allwin',
#   'rating': '8.007318054878931',
#   'link': '/title/tt0083922/'},
#  {'movie_title': 'Three Colors: Red',
#   'year': '1994',
#   'ranking': '250',
#   'star_cast': 'Krzysztof Kieslowski (dir.), Irène Jacob, Jean-Louis Trintignant',
#   'rating': '8.007167294658304',
#   'link': '/title/tt0111495/'}]

# %%
#Last, I'll create a dataframe from that dictionary
pd.DataFrame(imdb)
# Out:
#                   movie_title  year ranking  \
# 0    The Shawshank Redemption  1994       1
# 1               The Godfather  1972       2
# 2      The Godfather: Part II  1974       3
# 3             The Dark Knight  2008       4
# 4                12 Angry Men  1957       5
# ..                        ...   ...     ...
# 245            The Terminator  1984     246
# 246                Tangerines  2013     247
# 247                   Aladdin  1992     248
# 248       Fanny and Alexander  1982     249
# 249         Three Colors: Red  1994     250
#
#                                              star_cast             rating  \
# 0    Frank Darabont (dir.), Tim Robbins, Morgan Fre...  9.222790917333004
# 1    Francis Ford Coppola (dir.), Marlon Brando, Al...   9.14877186687596
# 2    Francis Ford Coppola (dir.), Al Pacino, Robert...  8.981171792324258
# 3    Christopher Nolan (dir.), Christian Bale, Heat...  8.973475292618291
# 4        Sidney Lumet (dir.), Henry Fonda, Lee J. Cobb  8.930520290799217
# ..                                                 ...                ...
# 245  James Cameron (dir.), Arnold Schwarzenegger, L...  8.009027432599156
# 246  Zaza Urushadze (dir.), Lembit Ulfsak, Elmo Nüg...  8.008279594204877
# 247  Ron Clements (dir.), Scott Weinger, Robin Will...  8.007409185119814
# 248  Ingmar Bergman (dir.), Bertil Guve, Pernilla A...  8.007318054878931
# 249  Krzysztof Kieslowski (dir.), Irène Jacob, Jean...  8.007167294658304
#
#                   link
# 0    /title/tt0111161/
# 1    /title/tt0068646/
# 2    /title/tt0071562/
# 3    /title/tt0468569/
# 4    /title/tt0050083/
# ..                 ...
# 245  /title/tt0088247/
# 246  /title/tt2991224/
# 247  /title/tt0103639/
# 248  /title/tt0083922/
# 249  /title/tt0111495/
#
# [250 rows x 6 columns]

# %%
# The Full code

# Download IMDB's Top 250 data
#(Let's quickly check out what it looks like)
url = 'http://www.imdb.com/chart/top'
response = requests.get(url)

imdb_soup = BeautifulSoup(response.text, 'lxml') #we're going to read the information we got with beautiful soup
# and it will read lxml and html code for you. learn more here: https://lxml.de/

movies = imdb_soup.select('td.titleColumn') #I'm going to select the title column
links = [a.attrs.get('href') for a in imdb_soup.select('td.titleColumn a')] #get the links
crew = [a.attrs.get('title') for a in imdb_soup.select('td.titleColumn a')] #get the crew
ratings = [b.attrs.get('data-value') for b in imdb_soup.select('td.posterColumn span[name=ir]')]
year = imdb_soup.select('span.secondaryInfo')#I'm going to select the year information

imdb = [] #creating an empty list

# Store each item into dictionary (data), then put those into a list (imdb)
for i in range(len(movies)):
    # Seperate movie into: 'place', 'title', 'year'
    movie_string = movies[i].get_text()
    movie = (' '.join(movie_string.split()).replace('.', ''))
    movie_title = movie[len(str(i))+1:-7]
    year_string = year[i].get_text()
    years = (' '.join(year_string.split()).replace('(', '').replace(')', ''))
    place = movie[:len(str(i))-(len(movie))]
    data = {"movie_title": movie_title,
            "year": years,
            "place": place,
            "star_cast": crew[i],
            "rating": ratings[i],
            "link": links[i]}
    imdb.append(data)

imdb = pd.DataFrame(imdb)
imdb['rating'] = imdb['rating'].astype(float).round(3) #rounding the values
# rating.round(2) #make it into a data frame

# voi-la easy-peasy data in your hands
imdb
# Out:
#                   movie_title  year place  \
# 0    The Shawshank Redemption  1994     1
# 1               The Godfather  1972     2
# 2      The Godfather: Part II  1974     3
# 3             The Dark Knight  2008     4
# 4                12 Angry Men  1957     5
# ..                        ...   ...   ...
# 245            The Terminator  1984   246
# 246                Tangerines  2013   247
# 247                   Aladdin  1992   248
# 248       Fanny and Alexander  1982   249
# 249         Three Colors: Red  1994   250
#
#                                              star_cast  rating  \
# 0    Frank Darabont (dir.), Tim Robbins, Morgan Fre...   9.223
# 1    Francis Ford Coppola (dir.), Marlon Brando, Al...   9.149
# 2    Francis Ford Coppola (dir.), Al Pacino, Robert...   8.981
# 3    Christopher Nolan (dir.), Christian Bale, Heat...   8.973
# 4        Sidney Lumet (dir.), Henry Fonda, Lee J. Cobb   8.931
# ..                                                 ...     ...
# 245  James Cameron (dir.), Arnold Schwarzenegger, L...   8.009
# 246  Zaza Urushadze (dir.), Lembit Ulfsak, Elmo Nüg...   8.008
# 247  Ron Clements (dir.), Scott Weinger, Robin Will...   8.007
# 248  Ingmar Bergman (dir.), Bertil Guve, Pernilla A...   8.007
# 249  Krzysztof Kieslowski (dir.), Irène Jacob, Jean...   8.007
#
#                   link
# 0    /title/tt0111161/
# 1    /title/tt0068646/
# 2    /title/tt0071562/
# 3    /title/tt0468569/
# 4    /title/tt0050083/
# ..                 ...
# 245  /title/tt0088247/
# 246  /title/tt2991224/
# 247  /title/tt0103639/
# 248  /title/tt0083922/
# 249  /title/tt0111495/
#
# [250 rows x 6 columns]

# %% [markdown]
# # Ethical considerations
#
# **You can scrape it, should you though?**
#
# A very good summary of practices for [ethical web scraping](https://towardsdatascience.com/ethics-in-web-scraping-b96b18136f01):
#
# * If you have a public API that provides the data I’m looking for, I’ll use it and avoid scraping all together.
# * I will only save the data I absolutely need from your page.
# * I will respect any content I do keep. I’ll never pass it off as my own.
# * I will look for ways to return value to you. Maybe I can drive some (real) traffic to your site or credit you in an article or post.
# * I will respond in a timely fashion to your outreach and work with you towards a resolution.
# * I will scrape for the purpose of creating new value from the data, not to duplicate it.
#
# Some other [important components](http://robertorocha.info/on-the-ethics-of-web-scraping/) of ethical web scraping practices include:
#
# * Read the Terms of Service and Privacy Policies of a website before scraping it (this might not be possible in many situations though).
# * If it’s not clear from looking at the website, contact the webmaster and ask if and what you’re allowed to harvest.
# * Be gentle on smaller websites
#     * Run your scraper in off-peak hours
#     * Space out your requests.
# * Identify yourself by name and email in your User-Agent strings.
# * Inspecting the **robots.txt** file for rules about what pages can be scraped, indexed, etc.
#
# ### What is a robots.txt?
#
# A simple text file placed on the web server which tells crawlers which file they can and cannot access. It's also called _The Robots Exclusion Protocol_.
#
# <img src='robots.png' width="600">
#
# #### Some examples

# %%
print(requests.get('https://www.imdb.com/robots.txt').text)

# %%
print(requests.get('https://www.nesta.org.uk/robots.txt').text)

# %%
print(requests.get('https://www.howtogeek.com/robots.txt').text)

# %% [markdown]
# #### What's a User-Agent?
#
# A User-Agent is a string identifying the browser and operating system to the web server. It's your machine's way of saying _Hi, I am Chrome on macOS_ to a web server.
#
# Web servers use user agents for a variety of purposes:
# * Serving different web pages to different web browsers. This can be used for good – for example, to serve simpler web pages to older browsers – or evil – for example, to display a “This web page must be viewed in Internet Explorer” message.
# * Displaying different content to different operating systems – for example, by displaying a slimmed-down page on mobile devices.
# * Gathering statistics showing the browsers and operating systems in use by their users. If you ever see browser market-share statistics, this is how they’re acquired.
#
# Let's break down the structure of a human-operated User-Agent:
#
# ```Mozilla/5.0 (iPad; U; CPU OS 3_2_1 like Mac OS X; en-us) AppleWebKit/531.21.10 (KHTML, like Gecko) Mobile/7B405```
#
# The components of this string are as follows:
#
# * Mozilla/5.0: Previously used to indicate compatibility with the Mozilla rendering engine.
# * (iPad; U; CPU OS 3_2_1 like Mac OS X; en-us): Details of the system in which the browser is running.
# * AppleWebKit/531.21.10: The platform the browser uses.
# * (KHTML, like Gecko): Browser platform details.
# * Mobile/7B405: This is used by the browser to indicate specific enhancements that are available directly in the browser or through third parties. An example of this is Microsoft Live Meeting which registers an extension so that the Live Meeting service knows if the software is already installed, which means it can provide a streamlined experience to joining meetings.
#
# When scraping websites, it is a good idea to include your contact information as a custom **User-Agent** string so that the webmaster can get in contact. For example:

# %%
headers = {
    'User-Agent': 'Mary Kaltenberg bot',
    'From': 'mkaltenberg@pace.edu'
}
request = requests.get('https://www.pace.edu/', headers=headers)
print(request.request.headers)

# %% [markdown]
# ## Advanced web scraping tools
# This section and example with exercise is from a tutorial done by Nesta *Thanks to Kostas Stathoulopoulos and Alex Bishop for this open source information and tutorial*
#
#
# **[Scrapy](https://scrapy.org)** is a Python framework for large scale web scraping. It gives you all the tools you need to efficiently extract data from websites, process them as you want, and store them in your preferred structure and format.
#
# **[ARGUS](https://github.com/datawizard1337/ARGUS)** is an easy-to-use web mining tool that's built on Scrapy. It is able to crawl a broad range of different websites.
#
# **[Selenium](https://selenium-python.readthedocs.io/index.html)** is an umbrella project encapsulating a variety of tools and libraries enabling web browser automation. Selenium specifically provides infrastructure for the W3C WebDriver specification — a platform and language-neutral coding interface compatible with all major web browsers. We can use it to imitate a user's behaviour and interact with Javascript elements (buttons, sliders etc.).
#
# For now, let's see how Selenium works.
#
# ### How to install Selenium
# 1. If you are using Anaconda: `conda install -c conda-forge selenium `
# 2. Download the driver for your web browser for [here](https://selenium-python.readthedocs.io/installation.html#drivers). **Note:** Choose a driver that corresponds to your web browser's version. Unzip the file and move the executable to your working directory.
#
# #### Important note on Selinium and web drivers
# If you are running this notebook locally, follow the above steps and run the code directly below (change the path to where your web driver is located). If you are running this notebook on colab, skip the next cell and run the one below it.
#
# ### Scraping data with Selenium
# We will use [UK's Yearly Box Office](https://www.boxofficemojo.com/intl/uk/yearly/) to scrape not only the top 100 but all the top movies of 2019. This will be our pipeline:
#
# <img src='selenium-pipeline.png' width='1024'>

# %% [markdown]
# ### Exercise
#
# Use Selenium to scrape Box Office Mojo's top \#100 for every year between 2002 and 2019.
#
# [Link to the solutions: NOTE THIS IS DATED AND HAS NOT BEEN CHECKED](https://colab.research.google.com/github/nestauk/im-tutorials/blob/3-ysi-tutorial/notebooks/Web-Scraping/solutions.ipynb)

# %% [markdown]
# ## Web Crawling
# #### The very grey area of collecting data
#
# Before webcrawling, think about (from WSP):
#
# * As you may know, just a few number of clicks can lead you down a rabit hole of unsavery information/content. Don't web crawl if for any reason you are uncomfortable with that possibility. Doesn't matter where you start, you can end up in a black hole of a dumpster fire.
#
# * What data am I trying to gather? Can this be accomplished by scraping just a few predefined websites (almost always the easier option), or does my crawler need to be able to discover new websites I might not know about?
#
# * When my crawler reaches a particular website, will it immediately follow the next outbound link to a new website, or will it stick around for a while and drill down into the current website?
#
# * Are there any conditions under which I would not want to scrape a particular site? Am I interested in non-English content?
#
# * How am I protecting myself against legal action if my web crawler catches the attention of a webmaster on one of the sites it runs across? (Check out Appendix C for more information on this subject.)
#
# * Be conscientiousa about how much bandwidth you are using and make every effort to determine if there’s a way to make the target server’s load easier
#
# * Check out Appendix C of WSP on pitfalls and considerations to legal considerations in the USA
#
# * Be careful about web-scraping from European websites especially concerning personal information. A useful guide can be found [here](https://blog.scrapinghub.com/web-scraping-gdpr-compliance-guide).
#
# <img src ="https://media.giphy.com/media/4BgQaxfQfeqys/giphy.gif">

# %% [markdown]
# ### Dark/Deep Web
# Many websites are note indexed by search engines - they can't go to websites that specifically exile them through the robots.txt file. These places are what's sometimes called the "deep web"  You can web scrape information in these places, I won't go into it, but there are a lot of resources out there that can show you how. Indexed websites(aka "googleable") are only a small percentage of what's out there.
#
# Dark web/Darknet is an entirely other thing. Its runs over an existing network infrastructure but uses a Tor client with an application protocol that runs on top of HTTP, providing a secure channel to exchange information. I've never attempted to scrape from here, so you'd be on your own if you do it.

# %% [markdown]
# ## Scrapy
#
# Scrapy is another package that is useful

# %% [markdown]
# ## Additional resources/references:
#
# * [Document Object Model (DOM)](https://developer.mozilla.org/en-US/docs/Web/API/Document_Object_Model/Introduction)
# * [HTML elements reference guide](https://www.w3schools.com/tags/default.asp)
# * [About /robots.txt](https://www.robotstxt.org/robotstxt.html)
# * [The robots.txt file](https://varvy.com/robottxt.html)
# * [Ethics in Web Scraping](https://towardsdatascience.com/ethics-in-web-scraping-b96b18136f01)
# * [On the Ethics of Web Scraping](http://robertorocha.info/on-the-ethics-of-web-scraping/)
# * [User-Agent](https://en.wikipedia.org/wiki/User_agent)
# * [BeautifulSoup documentation](https://www.crummy.com/software/BeautifulSoup/bs4/doc/)
# * [Selinium Python - Unofficial documentation](https://selenium-python.readthedocs.io/)
# * [ARGUS paper](http://ftp.zew.de/pub/zew-docs/dp/dp18033.pdf)
# * [Brian's C. Keegan](http://www.brianckeegan.com/) excellent [5-week web scraping course](https://github.com/CU-ITSS/Web-Data-Scraping-S2019) intended for researchers in the social sciences and humanities.

# %% [markdown]
# Note: Much of this tutorial is inspired by:
# - WSP book (cited in the syllabus)
# - [Grant McDermott's Lecture 6 Notes](https://raw.githack.com/uo-ec607/lectures/master/06-web-css/06-web-css.html)
# - Tutorial by Nesta (I used their code/examples)
